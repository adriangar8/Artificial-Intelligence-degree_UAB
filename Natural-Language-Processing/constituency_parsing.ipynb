# %% [markdown]
# # **Prerequisites**

# %%
# !pip install nltk
import nltk
from nltk.tokenize import RegexpTokenizer
from nltk.corpus import treebank
nltk.download('all')
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: nltk in /usr/local/lib/python3.9/dist-packages (3.7)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.9/dist-packages (from nltk) (4.65.0)
# Requirement already satisfied: click in /usr/local/lib/python3.9/dist-packages (from nltk) (8.1.3)
# Requirement already satisfied: joblib in /usr/local/lib/python3.9/dist-packages (from nltk) (1.1.1)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.9/dist-packages (from nltk) (2022.6.2)
# [nltk_data] Downloading collection 'all'
# [nltk_data]    |
# [nltk_data]    | Downloading package abc to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/abc.zip.
# [nltk_data]    | Downloading package alpino to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/alpino.zip.
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data]    | Downloading package averaged_perceptron_tagger_ru to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping
# [nltk_data]    |       taggers/averaged_perceptron_tagger_ru.zip.
# [nltk_data]    | Downloading package basque_grammars to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping grammars/basque_grammars.zip.
# [nltk_data]    | Downloading package bcp47 to /root/nltk_data...
# [nltk_data]    | Downloading package biocreative_ppi to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/biocreative_ppi.zip.
# [nltk_data]    | Downloading package bllip_wsj_no_aux to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping models/bllip_wsj_no_aux.zip.
# [nltk_data]    | Downloading package book_grammars to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping grammars/book_grammars.zip.
# [nltk_data]    | Downloading package brown to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/brown.zip.
# [nltk_data]    | Downloading package brown_tei to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/brown_tei.zip.
# [nltk_data]    | Downloading package cess_cat to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/cess_cat.zip.
# [nltk_data]    | Downloading package cess_esp to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/cess_esp.zip.
# [nltk_data]    | Downloading package chat80 to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/chat80.zip.
# [nltk_data]    | Downloading package city_database to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/city_database.zip.
# [nltk_data]    | Downloading package cmudict to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/cmudict.zip.
# [nltk_data]    | Downloading package comparative_sentences to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/comparative_sentences.zip.
# [nltk_data]    | Downloading package comtrans to /root/nltk_data...
# [nltk_data]    | Downloading package conll2000 to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/conll2000.zip.
# [nltk_data]    | Downloading package conll2002 to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/conll2002.zip.
# [nltk_data]    | Downloading package conll2007 to /root/nltk_data...
# [nltk_data]    | Downloading package crubadan to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/crubadan.zip.
# [nltk_data]    | Downloading package dependency_treebank to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/dependency_treebank.zip.
# [nltk_data]    | Downloading package dolch to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/dolch.zip.
# [nltk_data]    | Downloading package europarl_raw to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/europarl_raw.zip.
# [nltk_data]    | Downloading package extended_omw to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    | Downloading package floresta to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/floresta.zip.
# [nltk_data]    | Downloading package framenet_v15 to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/framenet_v15.zip.
# [nltk_data]    | Downloading package framenet_v17 to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/framenet_v17.zip.
# [nltk_data]    | Downloading package gazetteers to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/gazetteers.zip.
# [nltk_data]    | Downloading package genesis to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/genesis.zip.
# [nltk_data]    | Downloading package gutenberg to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/gutenberg.zip.
# [nltk_data]    | Downloading package ieer to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/ieer.zip.
# [nltk_data]    | Downloading package inaugural to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/inaugural.zip.
# [nltk_data]    | Downloading package indian to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/indian.zip.
# [nltk_data]    | Downloading package jeita to /root/nltk_data...
# [nltk_data]    | Downloading package kimmo to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/kimmo.zip.
# [nltk_data]    | Downloading package knbc to /root/nltk_data...
# [nltk_data]    | Downloading package large_grammars to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping grammars/large_grammars.zip.
# [nltk_data]    | Downloading package lin_thesaurus to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/lin_thesaurus.zip.
# [nltk_data]    | Downloading package mac_morpho to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/mac_morpho.zip.
# [nltk_data]    | Downloading package machado to /root/nltk_data...
# [nltk_data]    | Downloading package masc_tagged to /root/nltk_data...
# [nltk_data]    | Downloading package maxent_ne_chunker to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping chunkers/maxent_ne_chunker.zip.
# [nltk_data]    | Downloading package maxent_treebank_pos_tagger to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping taggers/maxent_treebank_pos_tagger.zip.
# [nltk_data]    | Downloading package moses_sample to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping models/moses_sample.zip.
# [nltk_data]    | Downloading package movie_reviews to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/movie_reviews.zip.
# [nltk_data]    | Downloading package mte_teip5 to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/mte_teip5.zip.
# [nltk_data]    | Downloading package mwa_ppdb to /root/nltk_data...
# [nltk_data]    |   Unzipping misc/mwa_ppdb.zip.
# [nltk_data]    | Downloading package names to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/names.zip.
# [nltk_data]    | Downloading package nombank.1.0 to /root/nltk_data...
# [nltk_data]    | Downloading package nonbreaking_prefixes to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/nonbreaking_prefixes.zip.
# [nltk_data]    | Downloading package nps_chat to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/nps_chat.zip.
# [nltk_data]    | Downloading package omw to /root/nltk_data...
# [nltk_data]    | Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]    | Downloading package opinion_lexicon to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/opinion_lexicon.zip.
# [nltk_data]    | Downloading package panlex_swadesh to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    | Downloading package paradigms to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/paradigms.zip.
# [nltk_data]    | Downloading package pe08 to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/pe08.zip.
# [nltk_data]    | Downloading package perluniprops to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping misc/perluniprops.zip.
# [nltk_data]    | Downloading package pil to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/pil.zip.
# [nltk_data]    | Downloading package pl196x to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/pl196x.zip.
# [nltk_data]    | Downloading package porter_test to /root/nltk_data...
# [nltk_data]    |   Unzipping stemmers/porter_test.zip.
# [nltk_data]    | Downloading package ppattach to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/ppattach.zip.
# [nltk_data]    | Downloading package problem_reports to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/problem_reports.zip.
# [nltk_data]    | Downloading package product_reviews_1 to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/product_reviews_1.zip.
# [nltk_data]    | Downloading package product_reviews_2 to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/product_reviews_2.zip.
# [nltk_data]    | Downloading package propbank to /root/nltk_data...
# [nltk_data]    | Downloading package pros_cons to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/pros_cons.zip.
# [nltk_data]    | Downloading package ptb to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/ptb.zip.
# [nltk_data]    | Downloading package punkt to /root/nltk_data...
# [nltk_data]    |   Unzipping tokenizers/punkt.zip.
# [nltk_data]    | Downloading package qc to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/qc.zip.
# [nltk_data]    | Downloading package reuters to /root/nltk_data...
# [nltk_data]    | Downloading package rslp to /root/nltk_data...
# [nltk_data]    |   Unzipping stemmers/rslp.zip.
# [nltk_data]    | Downloading package rte to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/rte.zip.
# [nltk_data]    | Downloading package sample_grammars to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping grammars/sample_grammars.zip.
# [nltk_data]    | Downloading package semcor to /root/nltk_data...
# [nltk_data]    | Downloading package senseval to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/senseval.zip.
# [nltk_data]    | Downloading package sentence_polarity to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/sentence_polarity.zip.
# [nltk_data]    | Downloading package sentiwordnet to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/sentiwordnet.zip.
# [nltk_data]    | Downloading package shakespeare to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/shakespeare.zip.
# [nltk_data]    | Downloading package sinica_treebank to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/sinica_treebank.zip.
# [nltk_data]    | Downloading package smultron to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/smultron.zip.
# [nltk_data]    | Downloading package snowball_data to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    | Downloading package spanish_grammars to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping grammars/spanish_grammars.zip.
# [nltk_data]    | Downloading package state_union to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/state_union.zip.
# [nltk_data]    | Downloading package stopwords to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/stopwords.zip.
# [nltk_data]    | Downloading package subjectivity to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/subjectivity.zip.
# [nltk_data]    | Downloading package swadesh to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/swadesh.zip.
# [nltk_data]    | Downloading package switchboard to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/switchboard.zip.
# [nltk_data]    | Downloading package tagsets to /root/nltk_data...
# [nltk_data]    |   Unzipping help/tagsets.zip.
# [nltk_data]    | Downloading package timit to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/timit.zip.
# [nltk_data]    | Downloading package toolbox to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/toolbox.zip.
# [nltk_data]    | Downloading package treebank to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/treebank.zip.
# [nltk_data]    | Downloading package twitter_samples to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/twitter_samples.zip.
# [nltk_data]    | Downloading package udhr to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/udhr.zip.
# [nltk_data]    | Downloading package udhr2 to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/udhr2.zip.
# [nltk_data]    | Downloading package unicode_samples to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/unicode_samples.zip.
# [nltk_data]    | Downloading package universal_tagset to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping taggers/universal_tagset.zip.
# [nltk_data]    | Downloading package universal_treebanks_v20 to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    | Downloading package vader_lexicon to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    | Downloading package verbnet to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/verbnet.zip.
# [nltk_data]    | Downloading package verbnet3 to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/verbnet3.zip.
# [nltk_data]    | Downloading package webtext to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/webtext.zip.
# [nltk_data]    | Downloading package wmt15_eval to /root/nltk_data...
# [nltk_data]    |   Unzipping models/wmt15_eval.zip.
# [nltk_data]    | Downloading package word2vec_sample to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping models/word2vec_sample.zip.
# [nltk_data]    | Downloading package wordnet to /root/nltk_data...
# [nltk_data]    | Downloading package wordnet2021 to /root/nltk_data...
# [nltk_data]    | Downloading package wordnet2022 to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/wordnet2022.zip.
# [nltk_data]    | Downloading package wordnet31 to /root/nltk_data...
# [nltk_data]    | Downloading package wordnet_ic to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/wordnet_ic.zip.
# [nltk_data]    | Downloading package words to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/words.zip.
# [nltk_data]    | Downloading package ycoe to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/ycoe.zip.
# [nltk_data]    |
# [nltk_data]  Done downloading collection all
# True

# %%
# define a sentence to be processed
sentence = "At eight o'clock on Thursday morning Arthur didn't feel very good."
# tokenize the sentence - resluting list of tokens
tokens = nltk.word_tokenize(sentence) # Tokenize

print(tokens, "\n")

"""
Part-of-speech (POS) tagging is the process of assigning a grammatical category or part of speech 
(such as noun, verb, adjective, adverb, pronoun, preposition, conjunction, etc.) to each word in a 
given text based on its definition, context, and relationship with other words in the sentence.
"""

# perform part- of- speech tagging on the tokens
tagged = nltk.pos_tag(tokens) # PoS tagging

print("PoS:", tagged, "\n")

# define a string to be processed with a regular expression
s = "Good muffins cost $3.88\nin New York. Please buy me two of them.\n\nThanks."
# create a regular expression tokenizer that matches words (\w+), dollar amounts (\$[\d\.]+), and non-whitespace characters (\S+)
tokenizer = RegexpTokenizer(r'\w+|\$[\d\.]+|\S+')
# tokenizer the string using the regular expression tokenizer
output = tokenizer.tokenize(s)

print(output, "\n")

# parse a sentence from the Treebank corpus and store the resulting parse tree
t = treebank.parsed_sents('wsj_0001.mrg')[0]
#t.draw()
# Out:
# ['At', 'eight', "o'clock", 'on', 'Thursday', 'morning', 'Arthur', 'did', "n't", 'feel', 'very', 'good', '.']
#
# PoS: [('At', 'IN'), ('eight', 'CD'), ("o'clock", 'NN'), ('on', 'IN'), ('Thursday', 'NNP'), ('morning', 'NN'), ('Arthur', 'NNP'), ('did', 'VBD'), ("n't", 'RB'), ('feel', 'VB'), ('very', 'RB'), ('good', 'JJ'), ('.', '.')]
#
# ['Good', 'muffins', 'cost', '$3.88', 'in', 'New', 'York', '.', 'Please', 'buy', 'me', 'two', 'of', 'them', '.', 'Thanks', '.']

# %% [markdown]
# # **Constituency parsing, non-probabilistic parsing (Context-free grammars)**
#
# Non-probabilistic parsing, also known as context-free parsing, uses a predefined set of grammar rules, known as context-free grammars, to generate parse trees for a given sentence. These rules specify the relationships between different constituents in a sentence and are based on the structure of the language being parsed. Non-probabilistic parsing is deterministic, meaning that it always produces the same parse tree for a given sentence, unlike probabilistic parsing, which can generate different parse trees based on the probability of different grammar rules being used.

# %% [markdown]
# # Exercise 1
#
# Using the NLTK instructions, tokenike and compute the PoS of these sentences.
#
# Print the result:
#
# • The Jamaica Observer reported that Usain Bolt broke the 100m record.
#
# • While hunting in Africa, I shot an elephant in my pajamas. How an elephant got
# into my pajamas I'll never know.

# %%
# define the sentences to be processed
sentence1 = "The Jamaica Observer reported that Usain Bolt broke the 100m record."
sentence2 = "While hunting in Africa, I shot an elephant in my pajamas. How an elephant got into my pajamas I'll never know."

# tokenize the sentences - resluting list of tokens
tokens1 = nltk.word_tokenize(sentence1) # Tokenize
tokens2 = nltk.word_tokenize(sentence2) # Tokenize

# perform part- of- speech tagging on the tokens
tagged1 = nltk.pos_tag(tokens1) # PoS tagging
tagged2 = nltk.pos_tag(tokens2) # PoS tagging

print("PoS:", tagged1, "\n")
print("PoS:", tagged2, "\n")
# Out:
# PoS: [('The', 'DT'), ('Jamaica', 'NNP'), ('Observer', 'NNP'), ('reported', 'VBD'), ('that', 'DT'), ('Usain', 'NNP'), ('Bolt', 'NNP'), ('broke', 'VBD'), ('the', 'DT'), ('100m', 'CD'), ('record', 'NN'), ('.', '.')]
#
# PoS: [('While', 'IN'), ('hunting', 'VBG'), ('in', 'IN'), ('Africa', 'NNP'), (',', ','), ('I', 'PRP'), ('shot', 'VBP'), ('an', 'DT'), ('elephant', 'NN'), ('in', 'IN'), ('my', 'PRP$'), ('pajamas', 'NN'), ('.', '.'), ('How', 'WRB'), ('an', 'DT'), ('elephant', 'JJ'), ('got', 'VBD'), ('into', 'IN'), ('my', 'PRP$'), ('pajamas', 'NN'), ('I', 'PRP'), ("'ll", 'MD'), ('never', 'RB'), ('know', 'VB'), ('.', '.')]

# %% [markdown]
# # Exercise 2
#
# *Modify the code to parse this list of texts (no need to parse Grouxo’s sentence anymore):
# mytexts = ["John saw a man with my telescope",
#  "Alex kissed the dog",
#  "the man with the telescope ate a sandwich in the park"]*

# %%
import nltk
from nltk import CFG

# Defining a grammar
groucho_grammar = CFG.fromstring("""
S -> NP VP
PP -> P NP
NP -> Det N | Det N PP | 'I' | 'You'
VP -> V NP | VP PP
Det -> 'an' | 'my'
N -> 'elephant' | 'pajamas'
V -> 'shot'
P -> 'in'
""")

# Printing the grammar
print("START grammar:",groucho_grammar.start())
print("PRODUCTIONS grammar:",groucho_grammar.productions())

text = "I shot an elephant in my pajamas"
text_tokens = nltk.word_tokenize(text)

# Parsing the text
parser = nltk.parse.chart.ChartParser(groucho_grammar,trace=2)
trees = parser.parse(text_tokens)
for t in trees:

 print(t)

"""
1. Importing the necessary libraries - The code imports the Natural Language Toolkit (nltk) library and the Context-Free Grammar 
(CFG) module from nltk.

2. Defining a grammar - The code defines a context-free grammar (CFG) using the CFG.fromstring() method. The grammar consists of 
rules for constructing sentences from noun phrases (NP) and verb phrases (VP).

3. Printing the grammar - The code prints the start symbol and production rules of the grammar using the start() and productions() 
methods.

4. Tokenizing the text - The code tokenizes the sentence "I shot an elephant in my pajamas" using the nltk.word_tokenize() method.

5. Parsing the text - The code creates a parser using the nltk.parse.chart.ChartParser() method and passes it the grammar and the 
tokenized sentence. It then parses the sentence using the parser.parse() method.

6. Displaying the parse trees - The code prints all possible parse trees for the sentence using a for loop to iterate through the 
parsed trees.

Each parse tree represents a possible way to construct the sentence according to the rules of the grammar. In this case, the sentence 
"I shot an elephant in my pajamas" can be parsed in two different ways, as shown by the two parse trees that are printed.
"""
# Out:
# START grammar: S
# PRODUCTIONS grammar: [S -> NP VP, PP -> P NP, NP -> Det N, NP -> Det N PP, NP -> 'I', NP -> 'You', VP -> V NP, VP -> VP PP, Det -> 'an', Det -> 'my', N -> 'elephant', N -> 'pajamas', V -> 'shot', P -> 'in']
# |.  I  . shot.  an .eleph.  in .  my .pajam.|
# Leaf Init Rule:
# |[-----]     .     .     .     .     .     .| [0:1] 'I'
# |.     [-----]     .     .     .     .     .| [1:2] 'shot'
# |.     .     [-----]     .     .     .     .| [2:3] 'an'
# |.     .     .     [-----]     .     .     .| [3:4] 'elephant'
# |.     .     .     .     [-----]     .     .| [4:5] 'in'
# |.     .     .     .     .     [-----]     .| [5:6] 'my'
# |.     .     .     .     .     .     [-----]| [6:7] 'pajamas'
# Bottom Up Predict Combine Rule:
# |[-----]     .     .     .     .     .     .| [0:1] NP -> 'I' *
# Bottom Up Predict Combine Rule:
# |[----->     .     .     .     .     .     .| [0:1] S  -> NP * VP
# Bottom Up Predict Combine Rule:
# |.     [-----]     .     .     .     .     .| [1:2] V  -> 'shot' *
# Bottom Up Predict Combine Rule:
# |.     [----->     .     .     .     .     .| [1:2] VP -> V * NP
# Bottom Up Predict Combine Rule:
# |.     .     [-----]     .     .     .     .| [2:3] Det -> 'an' *
# Bottom Up Predict Combine Rule:
# |.     .     [----->     .     .     .     .| [2:3] NP -> Det * N
# |.     .     [----->     .     .     .     .| [2:3] NP -> Det * N PP
# Bottom Up Predict Combine Rule:
# |.     .     .     [-----]     .     .     .| [3:4] N  -> 'elephant' *
# Single Edge Fundamental Rule:
# |.     .     [-----------]     .     .     .| [2:4] NP -> Det N *
# |.     .     [----------->     .     .     .| [2:4] NP -> Det N * PP
# Bottom Up Predict Combine Rule:
# |.     .     [----------->     .     .     .| [2:4] S  -> NP * VP
# Single Edge Fundamental Rule:
# |.     [-----------------]     .     .     .| [1:4] VP -> V NP *
# Bottom Up Predict Combine Rule:
# |.     [----------------->     .     .     .| [1:4] VP -> VP * PP
# Single Edge Fundamental Rule:
# |[-----------------------]     .     .     .| [0:4] S  -> NP VP *
# Bottom Up Predict Combine Rule:
# |.     .     .     .     [-----]     .     .| [4:5] P  -> 'in' *
# Bottom Up Predict Combine Rule:
# |.     .     .     .     [----->     .     .| [4:5] PP -> P * NP
# Bottom Up Predict Combine Rule:
# |.     .     .     .     .     [-----]     .| [5:6] Det -> 'my' *
# Bottom Up Predict Combine Rule:
# |.     .     .     .     .     [----->     .| [5:6] NP -> Det * N
# |.     .     .     .     .     [----->     .| [5:6] NP -> Det * N PP
# Bottom Up Predict Combine Rule:
# |.     .     .     .     .     .     [-----]| [6:7] N  -> 'pajamas' *
# Single Edge Fundamental Rule:
# |.     .     .     .     .     [-----------]| [5:7] NP -> Det N *
# |.     .     .     .     .     [----------->| [5:7] NP -> Det N * PP
# Bottom Up Predict Combine Rule:
# |.     .     .     .     .     [----------->| [5:7] S  -> NP * VP
# Single Edge Fundamental Rule:
# |.     .     .     .     [-----------------]| [4:7] PP -> P NP *
# Single Edge Fundamental Rule:
# |.     .     [-----------------------------]| [2:7] NP -> Det N PP *
# |.     [-----------------------------------]| [1:7] VP -> VP PP *
# Bottom Up Predict Combine Rule:
# |.     [----------------------------------->| [1:7] VP -> VP * PP
# Single Edge Fundamental Rule:
# |[=========================================]| [0:7] S  -> NP VP *
# Bottom Up Predict Combine Rule:
# |.     .     [----------------------------->| [2:7] S  -> NP * VP
# Single Edge Fundamental Rule:
# |.     [-----------------------------------]| [1:7] VP -> V NP *
# Bottom Up Predict Combine Rule:
# |.     [----------------------------------->| [1:7] VP -> VP * PP
# Single Edge Fundamental Rule:
# |[=========================================]| [0:7] S  -> NP VP *
# (S
#   (NP I)
#   (VP
#     (VP (V shot) (NP (Det an) (N elephant)))
#     (PP (P in) (NP (Det my) (N pajamas)))))
# (S
#   (NP I)
#   (VP
#     (V shot)
#     (NP (Det an) (N elephant) (PP (P in) (NP (Det my) (N pajamas))))))
# '\n1. Importing the necessary libraries - The code imports the Natural Language Toolkit (nltk) library and the Context-Free Grammar \n(CFG) module from nltk.\n\n2. Defining a grammar - The code defines a context-free grammar (CFG) using the CFG.fromstring() method. The grammar consists of \nrules for constructing sentences from noun phrases (NP) and verb phrases (VP).\n\n3. Printing the grammar - The code prints the start symbol and production rules of the grammar using the start() and productions() \nmethods.\n\n4. Tokenizing the text - The code tokenizes the sentence "I shot an elephant in my pajamas" using the nltk.word_tokenize() method.\n\n5. Parsing the text - The code creates a parser using the nltk.parse.chart.ChartParser() method and passes it the grammar and the \ntokenized sentence. It then parses the sentence using the parser.parse() method.\n\n6. Displaying the parse trees - The code prints all possible parse trees for the sentence using a for loop to iterate through the \nparsed trees.\n\nEach parse tree represents a possible way to construct the sentence according to the rules of the grammar. In this case, the sentence \n"I shot an elephant in my pajamas" can be parsed in two different ways, as shown by the two parse trees that are printed.\n'

# %%
# sentences to be processed
mytexts = ["John saw a man with my telescope", "Alex kissed the dog", "the man with the telescope ate a sandwich in the park"]

# definition of an CFG that can parse the sentences in mytexts
grammar = CFG.fromstring("""
S -> NP VP
PP -> P NP
NP -> Det N | Det N PP | 'I' | 'You'
VP -> V NP | VP PP
Det -> 'a' | 'my' | 'the'
N -> 'John' | 'man' | 'telescope' | 'Alex' | 'dog' | 'sandwich' | 'park'
V -> 'saw' | 'kissed' | 'ate' | 
P -> 'in' | 'with'
""")

# iterate over the list of sentences to be processed
for s in mytexts:

  # tokenize the sentence
  text_tokens = nltk.word_tokenize(s)

  # parse the sentence
  parser = nltk.parse.chart.ChartParser(grammar,trace=2)
  # get all the possible trees
  trees = parser.parse(text_tokens)
  for t in trees:

    print(t)
# Out:
# |. John. saw .  a  . man . with.  my .teles.|
# Leaf Init Rule:
# |[-----]     .     .     .     .     .     .| [0:1] 'John'
# |.     [-----]     .     .     .     .     .| [1:2] 'saw'
# |.     .     [-----]     .     .     .     .| [2:3] 'a'
# |.     .     .     [-----]     .     .     .| [3:4] 'man'
# |.     .     .     .     [-----]     .     .| [4:5] 'with'
# |.     .     .     .     .     [-----]     .| [5:6] 'my'
# |.     .     .     .     .     .     [-----]| [6:7] 'telescope'
# Empty Predict Rule:
# |#     .     .     .     .     .     .     .| [0:0] V  -> *
# |.     #     .     .     .     .     .     .| [1:1] V  -> *
# |.     .     #     .     .     .     .     .| [2:2] V  -> *
# |.     .     .     #     .     .     .     .| [3:3] V  -> *
# |.     .     .     .     #     .     .     .| [4:4] V  -> *
# |.     .     .     .     .     #     .     .| [5:5] V  -> *
# |.     .     .     .     .     .     #     .| [6:6] V  -> *
# |.     .     .     .     .     .     .     #| [7:7] V  -> *
# Bottom Up Predict Combine Rule:
# |[-----]     .     .     .     .     .     .| [0:1] N  -> 'John' *
# Bottom Up Predict Combine Rule:
# |.     [-----]     .     .     .     .     .| [1:2] V  -> 'saw' *
# Bottom Up Predict Combine Rule:
# |.     [----->     .     .     .     .     .| [1:2] VP -> V * NP
# Bottom Up Predict Combine Rule:
# |.     .     [-----]     .     .     .     .| [2:3] Det -> 'a' *
# Bottom Up Predict Combine Rule:
# |.     .     [----->     .     .     .     .| [2:3] NP -> Det * N
# |.     .     [----->     .     .     .     .| [2:3] NP -> Det * N PP
# Bottom Up Predict Combine Rule:
# |.     .     .     [-----]     .     .     .| [3:4] N  -> 'man' *
# Single Edge Fundamental Rule:
# |.     .     [-----------]     .     .     .| [2:4] NP -> Det N *
# |.     .     [----------->     .     .     .| [2:4] NP -> Det N * PP
# Bottom Up Predict Combine Rule:
# |.     .     [----------->     .     .     .| [2:4] S  -> NP * VP
# Single Edge Fundamental Rule:
# |.     [-----------------]     .     .     .| [1:4] VP -> V NP *
# Bottom Up Predict Combine Rule:
# |.     [----------------->     .     .     .| [1:4] VP -> VP * PP
# Bottom Up Predict Combine Rule:
# |.     .     .     .     [-----]     .     .| [4:5] P  -> 'with' *
# Bottom Up Predict Combine Rule:
# |.     .     .     .     [----->     .     .| [4:5] PP -> P * NP
# Bottom Up Predict Combine Rule:
# |.     .     .     .     .     [-----]     .| [5:6] Det -> 'my' *
# Bottom Up Predict Combine Rule:
# |.     .     .     .     .     [----->     .| [5:6] NP -> Det * N
# |.     .     .     .     .     [----->     .| [5:6] NP -> Det * N PP
# Bottom Up Predict Combine Rule:
# |.     .     .     .     .     .     [-----]| [6:7] N  -> 'telescope' *
# Single Edge Fundamental Rule:
# |.     .     .     .     .     [-----------]| [5:7] NP -> Det N *
# |.     .     .     .     .     [----------->| [5:7] NP -> Det N * PP
# Bottom Up Predict Combine Rule:
# |.     .     .     .     .     [----------->| [5:7] S  -> NP * VP
# Single Edge Fundamental Rule:
# |.     .     .     .     [-----------------]| [4:7] PP -> P NP *
# Single Edge Fundamental Rule:
# |.     .     [-----------------------------]| [2:7] NP -> Det N PP *
# |.     [-----------------------------------]| [1:7] VP -> VP PP *
# Bottom Up Predict Combine Rule:
# |.     [----------------------------------->| [1:7] VP -> VP * PP
# Bottom Up Predict Combine Rule:
# |.     .     [----------------------------->| [2:7] S  -> NP * VP
# Single Edge Fundamental Rule:
# |.     [-----------------------------------]| [1:7] VP -> V NP *
# Bottom Up Predict Combine Rule:
# |.     [----------------------------------->| [1:7] VP -> VP * PP
# Bottom Up Predict Combine Rule:
# |>     .     .     .     .     .     .     .| [0:0] VP -> V * NP
# Bottom Up Predict Combine Rule:
# |.     >     .     .     .     .     .     .| [1:1] VP -> V * NP
# Bottom Up Predict Combine Rule:
# |.     .     >     .     .     .     .     .| [2:2] VP -> V * NP
# Single Edge Fundamental Rule:
# |.     .     [-----------]     .     .     .| [2:4] VP -> V NP *
# |.     .     [-----------------------------]| [2:7] VP -> V NP *
# Bottom Up Predict Combine Rule:
# |.     .     [----------------------------->| [2:7] VP -> VP * PP
# Bottom Up Predict Combine Rule:
# |.     .     [----------->     .     .     .| [2:4] VP -> VP * PP
# Single Edge Fundamental Rule:
# |.     .     [-----------------------------]| [2:7] VP -> VP PP *
# Bottom Up Predict Combine Rule:
# |.     .     [----------------------------->| [2:7] VP -> VP * PP
# Bottom Up Predict Combine Rule:
# |.     .     .     >     .     .     .     .| [3:3] VP -> V * NP
# Bottom Up Predict Combine Rule:
# |.     .     .     .     >     .     .     .| [4:4] VP -> V * NP
# Bottom Up Predict Combine Rule:
# |.     .     .     .     .     >     .     .| [5:5] VP -> V * NP
# Single Edge Fundamental Rule:
# |.     .     .     .     .     [-----------]| [5:7] VP -> V NP *
# Bottom Up Predict Combine Rule:
# |.     .     .     .     .     [----------->| [5:7] VP -> VP * PP
# Bottom Up Predict Combine Rule:
# |.     .     .     .     .     .     >     .| [6:6] VP -> V * NP
# Bottom Up Predict Combine Rule:
# |.     .     .     .     .     .     .     >| [7:7] VP -> V * NP
# |.   Alex  .  kissed .   the   .   dog   .|
# Leaf Init Rule:
# |[---------]         .         .         .| [0:1] 'Alex'
# |.         [---------]         .         .| [1:2] 'kissed'
# |.         .         [---------]         .| [2:3] 'the'
# |.         .         .         [---------]| [3:4] 'dog'
# Empty Predict Rule:
# |#         .         .         .         .| [0:0] V  -> *
# |.         #         .         .         .| [1:1] V  -> *
# |.         .         #         .         .| [2:2] V  -> *
# |.         .         .         #         .| [3:3] V  -> *
# |.         .         .         .         #| [4:4] V  -> *
# Bottom Up Predict Combine Rule:
# |[---------]         .         .         .| [0:1] N  -> 'Alex' *
# Bottom Up Predict Combine Rule:
# |.         [---------]         .         .| [1:2] V  -> 'kissed' *
# Bottom Up Predict Combine Rule:
# |.         [--------->         .         .| [1:2] VP -> V * NP
# Bottom Up Predict Combine Rule:
# |.         .         [---------]         .| [2:3] Det -> 'the' *
# Bottom Up Predict Combine Rule:
# |.         .         [--------->         .| [2:3] NP -> Det * N
# |.         .         [--------->         .| [2:3] NP -> Det * N PP
# Bottom Up Predict Combine Rule:
# |.         .         .         [---------]| [3:4] N  -> 'dog' *
# Single Edge Fundamental Rule:
# |.         .         [-------------------]| [2:4] NP -> Det N *
# |.         .         [------------------->| [2:4] NP -> Det N * PP
# Bottom Up Predict Combine Rule:
# |.         .         [------------------->| [2:4] S  -> NP * VP
# Single Edge Fundamental Rule:
# |.         [-----------------------------]| [1:4] VP -> V NP *
# Bottom Up Predict Combine Rule:
# |.         [----------------------------->| [1:4] VP -> VP * PP
# Bottom Up Predict Combine Rule:
# |>         .         .         .         .| [0:0] VP -> V * NP
# Bottom Up Predict Combine Rule:
# |.         >         .         .         .| [1:1] VP -> V * NP
# Bottom Up Predict Combine Rule:
# |.         .         >         .         .| [2:2] VP -> V * NP
# Single Edge Fundamental Rule:
# |.         .         [-------------------]| [2:4] VP -> V NP *
# Bottom Up Predict Combine Rule:
# |.         .         [------------------->| [2:4] VP -> VP * PP
# Bottom Up Predict Combine Rule:
# |.         .         .         >         .| [3:3] VP -> V * NP
# Bottom Up Predict Combine Rule:
# |.         .         .         .         >| [4:4] VP -> V * NP
# |.the.man.wit.the.tel.ate. a .san. in.the.par.|
# Leaf Init Rule:
# |[---]   .   .   .   .   .   .   .   .   .   .| [0:1] 'the'
# |.   [---]   .   .   .   .   .   .   .   .   .| [1:2] 'man'
# |.   .   [---]   .   .   .   .   .   .   .   .| [2:3] 'with'
# |.   .   .   [---]   .   .   .   .   .   .   .| [3:4] 'the'
# |.   .   .   .   [---]   .   .   .   .   .   .| [4:5] 'telescope'
# |.   .   .   .   .   [---]   .   .   .   .   .| [5:6] 'ate'
# |.   .   .   .   .   .   [---]   .   .   .   .| [6:7] 'a'
# |.   .   .   .   .   .   .   [---]   .   .   .| [7:8] 'sandwich'
# |.   .   .   .   .   .   .   .   [---]   .   .| [8:9] 'in'
# |.   .   .   .   .   .   .   .   .   [---]   .| [9:10] 'the'
# |.   .   .   .   .   .   .   .   .   .   [---]| [10:11] 'park'
# Empty Predict Rule:
# |#   .   .   .   .   .   .   .   .   .   .   .| [0:0] V  -> *
# |.   #   .   .   .   .   .   .   .   .   .   .| [1:1] V  -> *
# |.   .   #   .   .   .   .   .   .   .   .   .| [2:2] V  -> *
# |.   .   .   #   .   .   .   .   .   .   .   .| [3:3] V  -> *
# |.   .   .   .   #   .   .   .   .   .   .   .| [4:4] V  -> *
# |.   .   .   .   .   #   .   .   .   .   .   .| [5:5] V  -> *
# |.   .   .   .   .   .   #   .   .   .   .   .| [6:6] V  -> *
# |.   .   .   .   .   .   .   #   .   .   .   .| [7:7] V  -> *
# |.   .   .   .   .   .   .   .   #   .   .   .| [8:8] V  -> *
# |.   .   .   .   .   .   .   .   .   #   .   .| [9:9] V  -> *
# |.   .   .   .   .   .   .   .   .   .   #   .| [10:10] V  -> *
# |.   .   .   .   .   .   .   .   .   .   .   #| [11:11] V  -> *
# Bottom Up Predict Combine Rule:
# |[---]   .   .   .   .   .   .   .   .   .   .| [0:1] Det -> 'the' *
# Bottom Up Predict Combine Rule:
# |[--->   .   .   .   .   .   .   .   .   .   .| [0:1] NP -> Det * N
# |[--->   .   .   .   .   .   .   .   .   .   .| [0:1] NP -> Det * N PP
# Bottom Up Predict Combine Rule:
# |.   [---]   .   .   .   .   .   .   .   .   .| [1:2] N  -> 'man' *
# Single Edge Fundamental Rule:
# |[-------]   .   .   .   .   .   .   .   .   .| [0:2] NP -> Det N *
# |[------->   .   .   .   .   .   .   .   .   .| [0:2] NP -> Det N * PP
# Bottom Up Predict Combine Rule:
# |[------->   .   .   .   .   .   .   .   .   .| [0:2] S  -> NP * VP
# Bottom Up Predict Combine Rule:
# |.   .   [---]   .   .   .   .   .   .   .   .| [2:3] P  -> 'with' *
# Bottom Up Predict Combine Rule:
# |.   .   [--->   .   .   .   .   .   .   .   .| [2:3] PP -> P * NP
# Bottom Up Predict Combine Rule:
# |.   .   .   [---]   .   .   .   .   .   .   .| [3:4] Det -> 'the' *
# Bottom Up Predict Combine Rule:
# |.   .   .   [--->   .   .   .   .   .   .   .| [3:4] NP -> Det * N
# |.   .   .   [--->   .   .   .   .   .   .   .| [3:4] NP -> Det * N PP
# Bottom Up Predict Combine Rule:
# |.   .   .   .   [---]   .   .   .   .   .   .| [4:5] N  -> 'telescope' *
# Single Edge Fundamental Rule:
# |.   .   .   [-------]   .   .   .   .   .   .| [3:5] NP -> Det N *
# |.   .   .   [------->   .   .   .   .   .   .| [3:5] NP -> Det N * PP
# Bottom Up Predict Combine Rule:
# |.   .   .   [------->   .   .   .   .   .   .| [3:5] S  -> NP * VP
# Single Edge Fundamental Rule:
# |.   .   [-----------]   .   .   .   .   .   .| [2:5] PP -> P NP *
# Single Edge Fundamental Rule:
# |[-------------------]   .   .   .   .   .   .| [0:5] NP -> Det N PP *
# Bottom Up Predict Combine Rule:
# |[------------------->   .   .   .   .   .   .| [0:5] S  -> NP * VP
# Bottom Up Predict Combine Rule:
# |.   .   .   .   .   [---]   .   .   .   .   .| [5:6] V  -> 'ate' *
# Bottom Up Predict Combine Rule:
# |.   .   .   .   .   [--->   .   .   .   .   .| [5:6] VP -> V * NP
# Bottom Up Predict Combine Rule:
# |.   .   .   .   .   .   [---]   .   .   .   .| [6:7] Det -> 'a' *
# Bottom Up Predict Combine Rule:
# |.   .   .   .   .   .   [--->   .   .   .   .| [6:7] NP -> Det * N
# |.   .   .   .   .   .   [--->   .   .   .   .| [6:7] NP -> Det * N PP
# Bottom Up Predict Combine Rule:
# |.   .   .   .   .   .   .   [---]   .   .   .| [7:8] N  -> 'sandwich' *
# Single Edge Fundamental Rule:
# |.   .   .   .   .   .   [-------]   .   .   .| [6:8] NP -> Det N *
# |.   .   .   .   .   .   [------->   .   .   .| [6:8] NP -> Det N * PP
# Bottom Up Predict Combine Rule:
# |.   .   .   .   .   .   [------->   .   .   .| [6:8] S  -> NP * VP
# Single Edge Fundamental Rule:
# |.   .   .   .   .   [-----------]   .   .   .| [5:8] VP -> V NP *
# Bottom Up Predict Combine Rule:
# |.   .   .   .   .   [----------->   .   .   .| [5:8] VP -> VP * PP
# Single Edge Fundamental Rule:
# |.   .   .   [-------------------]   .   .   .| [3:8] S  -> NP VP *
# |[-------------------------------]   .   .   .| [0:8] S  -> NP VP *
# Bottom Up Predict Combine Rule:
# |.   .   .   .   .   .   .   .   [---]   .   .| [8:9] P  -> 'in' *
# Bottom Up Predict Combine Rule:
# |.   .   .   .   .   .   .   .   [--->   .   .| [8:9] PP -> P * NP
# Bottom Up Predict Combine Rule:
# |.   .   .   .   .   .   .   .   .   [---]   .| [9:10] Det -> 'the' *
# Bottom Up Predict Combine Rule:
# |.   .   .   .   .   .   .   .   .   [--->   .| [9:10] NP -> Det * N
# |.   .   .   .   .   .   .   .   .   [--->   .| [9:10] NP -> Det * N PP
# Bottom Up Predict Combine Rule:
# |.   .   .   .   .   .   .   .   .   .   [---]| [10:11] N  -> 'park' *
# Single Edge Fundamental Rule:
# |.   .   .   .   .   .   .   .   .   [-------]| [9:11] NP -> Det N *
# |.   .   .   .   .   .   .   .   .   [------->| [9:11] NP -> Det N * PP
# Bottom Up Predict Combine Rule:
# |.   .   .   .   .   .   .   .   .   [------->| [9:11] S  -> NP * VP
# Single Edge Fundamental Rule:
# |.   .   .   .   .   .   .   .   [-----------]| [8:11] PP -> P NP *
# Single Edge Fundamental Rule:
# |.   .   .   .   .   .   [-------------------]| [6:11] NP -> Det N PP *
# |.   .   .   .   .   [-----------------------]| [5:11] VP -> VP PP *
# Bottom Up Predict Combine Rule:
# |.   .   .   .   .   [----------------------->| [5:11] VP -> VP * PP
# Single Edge Fundamental Rule:
# |.   .   .   [-------------------------------]| [3:11] S  -> NP VP *
# |[===========================================]| [0:11] S  -> NP VP *
# Bottom Up Predict Combine Rule:
# |.   .   .   .   .   .   [------------------->| [6:11] S  -> NP * VP
# Single Edge Fundamental Rule:
# |.   .   .   .   .   [-----------------------]| [5:11] VP -> V NP *
# Bottom Up Predict Combine Rule:
# |.   .   .   .   .   [----------------------->| [5:11] VP -> VP * PP
# Single Edge Fundamental Rule:
# |.   .   .   [-------------------------------]| [3:11] S  -> NP VP *
# |[===========================================]| [0:11] S  -> NP VP *
# Bottom Up Predict Combine Rule:
# |>   .   .   .   .   .   .   .   .   .   .   .| [0:0] VP -> V * NP
# Single Edge Fundamental Rule:
# |[-------]   .   .   .   .   .   .   .   .   .| [0:2] VP -> V NP *
# |[-------------------]   .   .   .   .   .   .| [0:5] VP -> V NP *
# Bottom Up Predict Combine Rule:
# |[------------------->   .   .   .   .   .   .| [0:5] VP -> VP * PP
# Bottom Up Predict Combine Rule:
# |[------->   .   .   .   .   .   .   .   .   .| [0:2] VP -> VP * PP
# Single Edge Fundamental Rule:
# |[-------------------]   .   .   .   .   .   .| [0:5] VP -> VP PP *
# Bottom Up Predict Combine Rule:
# |[------------------->   .   .   .   .   .   .| [0:5] VP -> VP * PP
# Bottom Up Predict Combine Rule:
# |.   >   .   .   .   .   .   .   .   .   .   .| [1:1] VP -> V * NP
# Bottom Up Predict Combine Rule:
# |.   .   >   .   .   .   .   .   .   .   .   .| [2:2] VP -> V * NP
# Bottom Up Predict Combine Rule:
# |.   .   .   >   .   .   .   .   .   .   .   .| [3:3] VP -> V * NP
# Single Edge Fundamental Rule:
# |.   .   .   [-------]   .   .   .   .   .   .| [3:5] VP -> V NP *
# Bottom Up Predict Combine Rule:
# |.   .   .   [------->   .   .   .   .   .   .| [3:5] VP -> VP * PP
# Bottom Up Predict Combine Rule:
# |.   .   .   .   >   .   .   .   .   .   .   .| [4:4] VP -> V * NP
# Bottom Up Predict Combine Rule:
# |.   .   .   .   .   >   .   .   .   .   .   .| [5:5] VP -> V * NP
# Bottom Up Predict Combine Rule:
# |.   .   .   .   .   .   >   .   .   .   .   .| [6:6] VP -> V * NP
# Single Edge Fundamental Rule:
# |.   .   .   .   .   .   [-------]   .   .   .| [6:8] VP -> V NP *
# |.   .   .   .   .   .   [-------------------]| [6:11] VP -> V NP *
# Bottom Up Predict Combine Rule:
# |.   .   .   .   .   .   [------------------->| [6:11] VP -> VP * PP
# Bottom Up Predict Combine Rule:
# |.   .   .   .   .   .   [------->   .   .   .| [6:8] VP -> VP * PP
# Single Edge Fundamental Rule:
# |.   .   .   .   .   .   [-------------------]| [6:11] VP -> VP PP *
# Bottom Up Predict Combine Rule:
# |.   .   .   .   .   .   [------------------->| [6:11] VP -> VP * PP
# Bottom Up Predict Combine Rule:
# |.   .   .   .   .   .   .   >   .   .   .   .| [7:7] VP -> V * NP
# Bottom Up Predict Combine Rule:
# |.   .   .   .   .   .   .   .   >   .   .   .| [8:8] VP -> V * NP
# Bottom Up Predict Combine Rule:
# |.   .   .   .   .   .   .   .   .   >   .   .| [9:9] VP -> V * NP
# Single Edge Fundamental Rule:
# |.   .   .   .   .   .   .   .   .   [-------]| [9:11] VP -> V NP *
# Bottom Up Predict Combine Rule:
# |.   .   .   .   .   .   .   .   .   [------->| [9:11] VP -> VP * PP
# Bottom Up Predict Combine Rule:
# |.   .   .   .   .   .   .   .   .   .   >   .| [10:10] VP -> V * NP
# Bottom Up Predict Combine Rule:
# |.   .   .   .   .   .   .   .   .   .   .   >| [11:11] VP -> V * NP
# (S
#   (NP (Det the) (N man) (PP (P with) (NP (Det the) (N telescope))))
#   (VP
#     (VP (V ate) (NP (Det a) (N sandwich)))
#     (PP (P in) (NP (Det the) (N park)))))
# (S
#   (NP (Det the) (N man) (PP (P with) (NP (Det the) (N telescope))))
#   (VP
#     (V ate)
#     (NP (Det a) (N sandwich) (PP (P in) (NP (Det the) (N park))))))

# %% [markdown]
# If the output consists of more than one parse tree, explain (maximum two sentences) why there is an ambiguity.

# %% [markdown]
# # Exercise 3
#
# *Write an example of a sentence that, although it is syntactically correct in English
# and uses the lexicon of the previous grammar, it cannot be parsed by the previous
# defined grammar.*

# %% [markdown]
# **I saw the man in the telescope with a sandwich.**
#
# In the given grammar, the VP (verb phrase) can be followed by either an NP (noun phrase) or a PP (prepositional phrase). However, the grammar does not allow for multiple PPs to modify the same verb in a single clause.
#
# In this example, the verb "saw" is modified by two prepositional phrases, "in the telescope" and "with a sandwich". Therefore, the sentence cannot be parsed by the given grammar.

# %% [markdown]
# # Exercise 4
#
# *Propose how to augment the previous parser to deal with sentences that may be
# incorrect, for example, containing spelling errors or mistakes arising from automatic
# speech recognition or handwritten text recognition (maximum 3 sentences).*

# %% [markdown]
# 1. Use of a spell checker in order to obtain suggestions for the misspelled words in the sentence.
#
# 2. With the obtained suggestions to substitute the misspelled word use a part of speech tagger to identfy the part of the speech each suggestion belongs to.
#
# 3. Use the corrected sentence and its part-of-speech tags to generate a set of candidate parse trees for each suggestion. Therefore n x m trees.
#
# 4. Use any kind of probabilistic model to determine the sentence with the higher pobability.
#
# *n- number of trees generated for a particular suggestion*
#
# *m - number of suggestions*

# %% [markdown]
# # **Constituency parsing, probabilistic parsing (Probabilistic Context-free grammars)**
#
# A PCFG is a type of formal grammar that assigns probabilities to each production rule in the grammar. These probabilities can be used to generate or parse sentences in the language defined by the grammar.

# %% [markdown]
# # Exercise 5
#
# *Execute this code, modifying the parameter trace (values from 1 to 3). Explain the
# differences. Print the parsing probability of the sentence "I saw the man with a
# telescope". Print the tree.*

# %% [markdown]
# *trace = 1*

# %%
import nltk
from nltk import PCFG

# definition of the probablistic context- free grammar
pcfg1 = PCFG.fromstring("""
S -> NP VP [1.0]
NP -> Det N [0.5] | NP PP [0.25] | 'John' [0.1] | 'I' [0.15]
Det -> 'the' [0.8] | 'a' [0.2]
N -> 'man' [0.5] | 'telescope' [0.5]
VP -> VP PP [0.1] | V NP [0.7] | V [0.2]
V -> 'ate' [0.35] | 'saw' [0.65]
PP -> P NP [1.0]
P -> 'with' [0.61] | 'in' [0.39]
""")

# definition of the sentence to be processed
text = "I saw the man with a telescope"
# tokenize the sentence
text_tokens = nltk.word_tokenize(text)

"""
The Viterbi parser is a dynamic programming algorithm that efficiently finds the most probable parse tree 
for a given sentence based on the probabilities specified in the PCFG. 
"""

# initialization of the Vierbi parser with the PCFG and the text tokens as input.
viterbi_parser = nltk.ViterbiParser(pcfg1,trace=1)
# generation of the trees
trees = viterbi_parser.parse(text_tokens)

# print out each tree
for tree in trees:

  print("Parsing tree:")
  print(tree)
  print("\nParsing probability:", tree.prob())
  #tree.draw()
# Out:
# Inserting tokens into the most likely constituents table...
# Finding the most likely constituents spanning 1 text elements...
# Finding the most likely constituents spanning 2 text elements...
# Finding the most likely constituents spanning 3 text elements...
# Finding the most likely constituents spanning 4 text elements...
# Finding the most likely constituents spanning 5 text elements...
# Finding the most likely constituents spanning 6 text elements...
# Finding the most likely constituents spanning 7 text elements...
# Parsing tree:
# (S
#   (NP I)
#   (VP
#     (V saw)
#     (NP
#       (NP (Det the) (N man))
#       (PP (P with) (NP (Det a) (N telescope)))))) (p=0.000104081)
#
# Parsing probability: 0.00010408124999999999

# %% [markdown]
# *trace = 2*

# %%
import nltk
from nltk import PCFG

# definition of the probablistic context- free grammar
pcfg1 = PCFG.fromstring("""
S -> NP VP [1.0]
NP -> Det N [0.5] | NP PP [0.25] | 'John' [0.1] | 'I' [0.15]
Det -> 'the' [0.8] | 'a' [0.2]
N -> 'man' [0.5] | 'telescope' [0.5]
VP -> VP PP [0.1] | V NP [0.7] | V [0.2]
V -> 'ate' [0.35] | 'saw' [0.65]
PP -> P NP [1.0]
P -> 'with' [0.61] | 'in' [0.39]
""")

# definition of the sentence to be processed
text = "I saw the man with a telescope"
# tokenize the sentence
text_tokens = nltk.word_tokenize(text)

"""
The Viterbi parser is a dynamic programming algorithm that efficiently finds the most probable parse tree 
for a given sentence based on the probabilities specified in the PCFG. 
"""

# initialization of the Vierbi parser with the PCFG and the text tokens as input.
viterbi_parser = nltk.ViterbiParser(pcfg1,trace=2)
# generation of the trees
trees = viterbi_parser.parse(text_tokens)

# print out each tree
for tree in trees:

  print("Parsing tree:")
  print(tree)
  print("\nParsing probability:", tree.prob())
  #tree.draw()
# Out:
# Inserting tokens into the most likely constituents table...
#    Insert: |=......| I
#    Insert: |.=.....| saw
#    Insert: |..=....| the
#    Insert: |...=...| man
#    Insert: |....=..| with
#    Insert: |.....=.| a
#    Insert: |......=| telescope
# Finding the most likely constituents spanning 1 text elements...
#    Insert: |=......| NP -> 'I' [0.15]
#    Insert: |.=.....| V -> 'saw' [0.65]
#    Insert: |.=.....| VP -> V [0.2]
#    Insert: |..=....| Det -> 'the' [0.8]
#    Insert: |...=...| N -> 'man' [0.5]
#    Insert: |....=..| P -> 'with' [0.61]
#    Insert: |.....=.| Det -> 'a' [0.2]
#    Insert: |......=| N -> 'telescope' [0.5]
# Finding the most likely constituents spanning 2 text elements...
#    Insert: |==.....| S -> NP VP [1.0]
#    Insert: |..==...| NP -> Det N [0.5]
#    Insert: |.....==| NP -> Det N [0.5]
# Finding the most likely constituents spanning 3 text elements...
#    Insert: |.===...| VP -> V NP [0.7]
#    Insert: |....===| PP -> P NP [1.0]
# Finding the most likely constituents spanning 4 text elements...
#    Insert: |====...| S -> NP VP [1.0]
# Finding the most likely constituents spanning 5 text elements...
#    Insert: |..=====| NP -> NP PP [0.25]
# Finding the most likely constituents spanning 6 text elements...
#    Insert: |.======| VP -> VP PP [0.1]
#    Insert: |.======| VP -> V NP [0.7]
#   Discard: |.======| VP -> VP PP [0.1]
# Finding the most likely constituents spanning 7 text elements...
#    Insert: |=======| S -> NP VP [1.0]
# Parsing tree:
# (S
#   (NP I)
#   (VP
#     (V saw)
#     (NP
#       (NP (Det the) (N man))
#       (PP (P with) (NP (Det a) (N telescope)))))) (p=0.000104081)
#
# Parsing probability: 0.00010408124999999999

# %% [markdown]
# *trace = 3*

# %%
import nltk
from nltk import PCFG

# definition of the probablistic context- free grammar
pcfg1 = PCFG.fromstring("""
S -> NP VP [1.0]
NP -> Det N [0.5] | NP PP [0.25] | 'John' [0.1] | 'I' [0.15]
Det -> 'the' [0.8] | 'a' [0.2]
N -> 'man' [0.5] | 'telescope' [0.5]
VP -> VP PP [0.1] | V NP [0.7] | V [0.2]
V -> 'ate' [0.35] | 'saw' [0.65]
PP -> P NP [1.0]
P -> 'with' [0.61] | 'in' [0.39]
""")

# definition of the sentence to be processed
text = "I saw the man with a telescope"
# tokenize the sentence
text_tokens = nltk.word_tokenize(text)

"""
The Viterbi parser is a dynamic programming algorithm that efficiently finds the most probable parse tree 
for a given sentence based on the probabilities specified in the PCFG. 
"""

# initialization of the Vierbi parser with the PCFG and the text tokens as input.
viterbi_parser = nltk.ViterbiParser(pcfg1,trace=3)
# generation of the trees
trees = viterbi_parser.parse(text_tokens)

# print out each tree
for tree in trees:

  print("Parsing tree:")
  print(tree)
  print("\nParsing probability:", tree.prob())
 #tree.draw()
# Out:
# Inserting tokens into the most likely constituents table...
#    Insert: |=......| I
#    Insert: |.=.....| saw
#    Insert: |..=....| the
#    Insert: |...=...| man
#    Insert: |....=..| with
#    Insert: |.....=.| a
#    Insert: |......=| telescope
# Finding the most likely constituents spanning 1 text elements...
#    Insert: |=......| NP -> 'I' [0.15]               0.1500000000
#    Insert: |.=.....| V -> 'saw' [0.65]              0.6500000000
#    Insert: |.=.....| VP -> V [0.2]                  0.1300000000
#    Insert: |..=....| Det -> 'the' [0.8]             0.8000000000
#    Insert: |...=...| N -> 'man' [0.5]               0.5000000000
#    Insert: |....=..| P -> 'with' [0.61]             0.6100000000
#    Insert: |.....=.| Det -> 'a' [0.2]               0.2000000000
#    Insert: |......=| N -> 'telescope' [0.5]         0.5000000000
# Finding the most likely constituents spanning 2 text elements...
#    Insert: |==.....| S -> NP VP [1.0]               0.0195000000
#    Insert: |..==...| NP -> Det N [0.5]              0.2000000000
#    Insert: |.....==| NP -> Det N [0.5]              0.0500000000
# Finding the most likely constituents spanning 3 text elements...
#    Insert: |.===...| VP -> V NP [0.7]               0.0910000000
#    Insert: |....===| PP -> P NP [1.0]               0.0305000000
# Finding the most likely constituents spanning 4 text elements...
#    Insert: |====...| S -> NP VP [1.0]               0.0136500000
# Finding the most likely constituents spanning 5 text elements...
#    Insert: |..=====| NP -> NP PP [0.25]             0.0015250000
# Finding the most likely constituents spanning 6 text elements...
#    Insert: |.======| VP -> VP PP [0.1]              0.0002775500
#    Insert: |.======| VP -> V NP [0.7]               0.0006938750
#   Discard: |.======| VP -> VP PP [0.1]              0.0002775500
# Finding the most likely constituents spanning 7 text elements...
#    Insert: |=======| S -> NP VP [1.0]               0.0001040812
# Parsing tree:
# (S
#   (NP I)
#   (VP
#     (V saw)
#     (NP
#       (NP (Det the) (N man))
#       (PP (P with) (NP (Det a) (N telescope)))))) (p=0.000104081)
#
# Parsing probability: 0.00010408124999999999

# %% [markdown]
# **Conclusion:**
#
# It must be pointed out that the 'trace' paremeter in the Viterbi parser is responsable for the amount of debugging information displayed during the parsing process. Therefore, it can be said that setting 'trace' to a value of 3 will result in a higher level of information in comparisson to setting 'trace' to a value of 1 or 2.

# %% [markdown]
# # Exercise 6
# *Since the sentence has two possible parse trees, modify the grammar probabilities to
# force the other parsing tree to be more probable. Print the new probability and the
# tree.*

# %%
# definition of the probablistic context- free grammar
pcfg1 = PCFG.fromstring("""
S -> NP VP [1.0]
NP -> Det N [0.5] | NP PP [0.25] | 'John' [0.1] | 'I' [0.15]
Det -> 'the' [0.8] | 'a' [0.2]
N -> 'man' [0.5] | 'telescope' [0.5]
VP -> VP PP [0.3] | V NP [0.5] | V [0.2]
V -> 'ate' [0.35] | 'saw' [0.65]
PP -> P NP [1.0]
P -> 'with' [0.61] | 'in' [0.39]
""")

# definition of the sentence to be processed
text = "I saw the man with a telescope"
# tokenize the sentence
text_tokens = nltk.word_tokenize(text)

"""
The Viterbi parser is a dynamic programming algorithm that efficiently finds the most probable parse tree 
for a given sentence based on the probabilities specified in the PCFG. 
"""

# initialization of the Vierbi parser with the PCFG and the text tokens as input.
viterbi_parser = nltk.ViterbiParser(pcfg1,trace=3)
# generation of the trees
trees = viterbi_parser.parse(text_tokens)

# print out each tree
for tree in trees:

  print("Parsing tree:")
  print(tree)
  print("\nParsing probability:", tree.prob())
 #tree.draw()
# Out:
# Inserting tokens into the most likely constituents table...
#    Insert: |=......| I
#    Insert: |.=.....| saw
#    Insert: |..=....| the
#    Insert: |...=...| man
#    Insert: |....=..| with
#    Insert: |.....=.| a
#    Insert: |......=| telescope
# Finding the most likely constituents spanning 1 text elements...
#    Insert: |=......| NP -> 'I' [0.15]               0.1500000000
#    Insert: |.=.....| V -> 'saw' [0.65]              0.6500000000
#    Insert: |.=.....| VP -> V [0.2]                  0.1300000000
#    Insert: |..=....| Det -> 'the' [0.8]             0.8000000000
#    Insert: |...=...| N -> 'man' [0.5]               0.5000000000
#    Insert: |....=..| P -> 'with' [0.61]             0.6100000000
#    Insert: |.....=.| Det -> 'a' [0.2]               0.2000000000
#    Insert: |......=| N -> 'telescope' [0.5]         0.5000000000
# Finding the most likely constituents spanning 2 text elements...
#    Insert: |==.....| S -> NP VP [1.0]               0.0195000000
#    Insert: |..==...| NP -> Det N [0.5]              0.2000000000
#    Insert: |.....==| NP -> Det N [0.5]              0.0500000000
# Finding the most likely constituents spanning 3 text elements...
#    Insert: |.===...| VP -> V NP [0.5]               0.0650000000
#    Insert: |....===| PP -> P NP [1.0]               0.0305000000
# Finding the most likely constituents spanning 4 text elements...
#    Insert: |====...| S -> NP VP [1.0]               0.0097500000
# Finding the most likely constituents spanning 5 text elements...
#    Insert: |..=====| NP -> NP PP [0.25]             0.0015250000
# Finding the most likely constituents spanning 6 text elements...
#    Insert: |.======| VP -> VP PP [0.3]              0.0005947500
#   Discard: |.======| VP -> V NP [0.5]               0.0004956250
#   Discard: |.======| VP -> V NP [0.5]               0.0004956250
# Finding the most likely constituents spanning 7 text elements...
#    Insert: |=======| S -> NP VP [1.0]               0.0000892125
# Parsing tree:
# (S
#   (NP I)
#   (VP
#     (VP (V saw) (NP (Det the) (N man)))
#     (PP (P with) (NP (Det a) (N telescope))))) (p=8.92125e-05)
#
# Parsing probability: 8.92125e-05

# %% [markdown]
# It must be pointed out that in this modified PCFG the probability of 'VP -> VP PP [0.3]' has been increased to favor the parse tree where "I" have the telescope. Also, note that the probability of the rule 'VP -> V NP [0.7] has been decreased in order to make the other tree less probable.

# %% [markdown]
# # Exercise 7
# *Execute this code, modifying the parameter trace (values from 1 to 2). Print the output tree and the probability.*

# %% [markdown]
# *trace = 1*

# %%
import nltk
from nltk.corpus import treebank

productions=[]
S=nltk.Nonterminal('S')
for f in treebank.fileids():

  for tree in treebank.parsed_sents(f):

    productions+=tree.productions()

grammar=nltk.induce_pcfg(S,productions)

for p in grammar.productions()[1:25]:

  print(p)

myparser = nltk.ViterbiParser(grammar,1)
text = "the boy jumps over the board"
mytokens = nltk.word_tokenize(text)

# Viterbi parse the sentence and get the most likely parse tree
myparsing = next(myparser.parse(mytokens))

# print the most likely parse tree and its probability
print(myparsing)
print("Probability:", myparsing.prob())
# Out:
# NP-SBJ -> NP , ADJP , [0.000392567]
# NP -> NNP NNP [0.0309391]
# NNP -> 'Pierre' [0.00010627]
# NNP -> 'Vinken' [0.00021254]
# , -> ',' [0.999795]
# ADJP -> NP JJ [0.014556]
# NP -> CD NNS [0.0110015]
# CD -> '61' [0.00141004]
# NNS -> 'years' [0.0190177]
# JJ -> 'old' [0.00411382]
# VP -> MD VP [0.0523088]
# MD -> 'will' [0.30205]
# VP -> VB NP PP-CLR NP-TMP [0.000137836]
# VB -> 'join' [0.00156617]
# NP -> DT NN [0.0851458]
# DT -> 'the' [0.49455]
# NN -> 'board' [0.0022786]
# PP-CLR -> IN NP [0.679445]
# IN -> 'as' [0.0337831]
# NP -> DT JJ NN [0.031192]
# DT -> 'a' [0.229516]
# JJ -> 'nonexecutive' [0.000857045]
# NN -> 'director' [0.0024305]
# NP-TMP -> NNP CD [0.0437158]
# Inserting tokens into the most likely constituents table...
# Finding the most likely constituents spanning 1 text elements...
# Finding the most likely constituents spanning 2 text elements...
# Finding the most likely constituents spanning 3 text elements...
# Finding the most likely constituents spanning 4 text elements...
# Finding the most likely constituents spanning 5 text elements...
# Finding the most likely constituents spanning 6 text elements...
# (S
#   (NP-SBJ (DT the) (NN boy))
#   (NP-PRD
#     (NP (NNS jumps))
#     (PP (IN over) (NP (DT the) (NN board))))) (p=1.25001e-20)
# Probability: 1.2500082459723783e-20

# %% [markdown]
# *trace = 2*

# %%
import nltk
from nltk.corpus import treebank

productions=[]
S=nltk.Nonterminal('S')
for f in treebank.fileids():

  for tree in treebank.parsed_sents(f):

    productions+=tree.productions()

grammar=nltk.induce_pcfg(S,productions)

"""
for p in grammar.productions()[1:25]:

  print(p)
"""

myparser = nltk.ViterbiParser(grammar,2)
text = "the boy jumps over the board"
mytokens = nltk.word_tokenize(text)
# Viterbi parse the sentence and get the most likely parse tree
myparsing = next(myparser.parse(mytokens))

# print the most likely parse tree and its probability
print(myparsing)
print("Probability:", myparsing.prob())
# Out:
# Streaming output truncated to the last 5000 lines.
#   Discard: |======| NP-SBJ -> NP-TTL PP [0.000130856]
#   Discard: |======| NP-SBJ -> NP-TTL PP [0.000130856]
#   Discard: |======| S -> NP-TTL-SBJ ADVP-TMP VP [0.000115607]
#   Discard: |======| S -> NP-TTL-SBJ ADVP-TMP VP [0.000115607]
#   Discard: |======| S -> NP-TTL-SBJ ADVP-TMP VP [0.000115607]
#   Discard: |======| NP -> NP PP S-1 [0.00029506]
#   Discard: |======| NP -> NP PP S-1 [0.00029506]
#   Discard: |======| NP -> NP PP S-1 [0.00029506]
#   Discard: |======| NP-SBJ -> NP PP PP-DIR [0.000130856]
#   Discard: |======| NP -> ADJP JJ NN [0.000168606]
#   Discard: |======| NP -> NP NNS S [8.43028e-05]
#   Discard: |======| NP-PRD -> NP PP S-4 [0.00357143]
#   Discard: |======| NP-PRD -> NP PP S-4 [0.00357143]
#   Discard: |======| NP-PRD -> NP PP S-4 [0.00357143]
#   Discard: |======| S-TPC-3 -> NP-SBJ ADVP VP [0.0833333]
#   Discard: |======| S-TPC-3 -> NP-SBJ ADVP VP [0.0833333]
#   Discard: |======| S-TPC-3 -> NP-SBJ ADVP VP [0.0833333]
#   Discard: |======| S-TPC-3 -> NP-SBJ ADVP VP [0.0833333]
#   Discard: |======| S-TPC-3 -> NP-SBJ ADVP VP [0.0833333]
#   Discard: |======| S-TPC-3 -> NP-SBJ ADVP VP [0.0833333]
#   Discard: |======| S-TPC-3 -> NP-SBJ ADVP VP [0.0833333]
#    Insert: |======| PP-LOC-PRD -> ADVP IN NP [0.0555556]
#   Discard: |======| NP -> NP PP ADVP [8.43028e-05]
#   Discard: |======| NP -> NP PP ADVP [8.43028e-05]
#   Discard: |======| NP -> NP PP ADVP [8.43028e-05]
#   Discard: |======| NP -> NP PP ADVP [8.43028e-05]
#   Discard: |======| S-TPC-2 -> NP-SBJ ADVP-TMP VP [0.0235294]
#   Discard: |======| S-TPC-2 -> NP-SBJ ADVP-TMP VP [0.0235294]
#   Discard: |======| S-TPC-2 -> NP-SBJ ADVP-TMP VP [0.0235294]
#   Discard: |======| S-TPC-2 -> NP-SBJ ADVP-TMP VP [0.0235294]
#   Discard: |======| S-TPC-2 -> NP-SBJ ADVP-TMP VP [0.0235294]
#   Discard: |======| S-TPC-2 -> NP-SBJ ADVP-TMP VP [0.0235294]
#   Discard: |======| S-TPC-2 -> NP-SBJ ADVP-TMP VP [0.0235294]
#   Discard: |======| S-TPC-2 -> NP-SBJ ADVP-TMP VP [0.0235294]
#   Discard: |======| NP -> NP SBAR-PRP [0.000463665]
#   Discard: |======| S -> ADVP-TMP NP-SBJ VP [0.000462428]
#   Discard: |======| S -> ADVP-TMP NP-SBJ VP [0.000462428]
#   Discard: |======| S -> ADVP-TMP NP-SBJ VP [0.000462428]
#   Discard: |======| S -> ADVP-TMP NP-SBJ VP [0.000462428]
#   Discard: |======| S -> ADVP-TMP NP-SBJ VP [0.000462428]
#   Discard: |======| S -> ADVP-TMP NP-SBJ VP [0.000462428]
#   Discard: |======| S -> ADVP-TMP NP-SBJ VP [0.000462428]
#   Discard: |======| ADJP-PRD -> JJ PP-DIR [0.00166113]
#   Discard: |======| S -> NP-TMP NP-SBJ-3 VP [0.000115607]
#   Discard: |======| S -> NP-TMP NP-SBJ-3 VP [0.000115607]
#   Discard: |======| S -> NP-TMP NP-SBJ-3 VP [0.000115607]
#   Discard: |======| S -> NP-TMP NP-SBJ-3 VP [0.000115607]
#   Discard: |======| S -> NP-TMP NP-SBJ-3 VP [0.000115607]
#   Discard: |======| S -> NP-TMP NP-SBJ-3 VP [0.000115607]
#   Discard: |======| S -> NP-TMP NP-SBJ-3 VP [0.000115607]
#   Discard: |======| S -> NP-TMP NP-SBJ-3 VP [0.000115607]
#   Discard: |======| NP-PRD -> NP SBAR-LOC [0.00178571]
#   Discard: |======| S-NOM-SBJ -> NP-SBJ-1 VP [0.0434783]
#   Discard: |======| S-NOM-SBJ -> NP-SBJ-1 VP [0.0434783]
#   Discard: |======| S-NOM-SBJ -> NP-SBJ-1 VP [0.0434783]
#   Discard: |======| S-NOM-SBJ -> NP-SBJ-1 VP [0.0434783]
#   Discard: |======| S-NOM-SBJ -> NP-SBJ-1 VP [0.0434783]
#   Discard: |======| S-NOM -> NP-SBJ-2 VP [0.0223642]
#   Discard: |======| S-NOM -> NP-SBJ-2 VP [0.0223642]
#   Discard: |======| S-NOM -> NP-SBJ-2 VP [0.0223642]
#   Discard: |======| S-NOM -> NP-SBJ-2 VP [0.0223642]
#   Discard: |======| S-NOM -> NP-SBJ-2 VP [0.0223642]
#   Discard: |======| NP-PRD -> NP VP PP [0.00178571]
#   Discard: |======| NP-PRD -> NP VP PP [0.00178571]
#   Discard: |======| NP-PRD -> NP VP PP [0.00178571]
#   Discard: |======| NP-PRD -> NP VP PP [0.00178571]
#   Discard: |======| NP-PRD -> NP VP PP [0.00178571]
#   Discard: |======| NP -> NP NNS SBAR [4.21514e-05]
#   Discard: |======| ADJP-PRD -> JJ NP-TMP [0.00166113]
#   Discard: |======| NP -> DT NAC NN [8.43028e-05]
#   Discard: |======| PP-TMP -> NP IN S-NOM [0.00119474]
#   Discard: |======| NP -> NP PP-TMP PP [0.000168606]
#   Discard: |======| NP -> NP ADJP NN [0.000210757]
#   Discard: |======| NP -> NP ADJP NN [0.000210757]
#   Discard: |======| NP -> NP ADJP NN [0.000210757]
#   Discard: |======| NP -> NP ADJP NN [0.000210757]
#   Discard: |======| NP -> NP PP RRC [4.21514e-05]
#   Discard: |======| NP -> NP PP RRC [4.21514e-05]
#   Discard: |======| NP -> NP PP RRC [4.21514e-05]
#   Discard: |======| NP -> NP PP RRC [4.21514e-05]
#   Discard: |======| NP -> NP PP RRC [4.21514e-05]
#   Discard: |======| NP -> NP PP RRC [4.21514e-05]
#   Discard: |======| RRC -> ADJP PP-LOC PP [0.1]
#   Discard: |======| S-NOM -> NP-SBJ IN VP [0.00319489]
#   Discard: |======| S -> NP-SBJ-2 ADVP VP [0.000231214]
#   Discard: |======| S -> NP-SBJ-2 ADVP VP [0.000231214]
#   Discard: |======| S -> NP-SBJ-2 ADVP VP [0.000231214]
#   Discard: |======| S -> NP-SBJ-2 ADVP VP [0.000231214]
#   Discard: |======| S -> NP-SBJ-2 ADVP VP [0.000231214]
#   Discard: |======| S -> NP-SBJ-2 ADVP VP [0.000231214]
#   Discard: |======| S -> NP-SBJ-2 ADVP VP [0.000231214]
#   Discard: |======| S -> ADVP NP-SBJ-1 VP [0.000231214]
#   Discard: |======| S -> ADVP NP-SBJ-1 VP [0.000231214]
#   Discard: |======| S -> ADVP NP-SBJ-1 VP [0.000231214]
#   Discard: |======| S -> ADVP NP-SBJ-1 VP [0.000231214]
#   Discard: |======| S -> ADVP NP-SBJ-1 VP [0.000231214]
#   Discard: |======| S -> ADVP NP-SBJ-1 VP [0.000231214]
#   Discard: |======| S -> ADVP NP-SBJ-1 VP [0.000231214]
#    Insert: |======| RRC -> ADJP NP-TMP [0.1]
#   Discard: |======| RRC -> ADJP NP-TMP [0.1]
#   Discard: |======| RRC -> ADJP NP-TMP [0.1]
#    Insert: |======| RRC -> ADJP NP-TMP [0.1]
#   Discard: |======| RRC -> ADJP NP-TMP [0.1]
#   Discard: |======| NP -> NP PP-LOC VP [0.000126454]
#   Discard: |======| NP -> NP PP-LOC VP [0.000126454]
#   Discard: |======| NP-SBJ -> DT ADJP JJ NN [0.000130856]
#    Insert: |======| NX-1 -> NP SBAR [0.5]
#    Insert: |======| NX -> NX PP [0.0232558]
#    Insert: |======| NX -> NX PP [0.0232558]
#   Discard: |======| NX -> NX PP [0.0232558]
#   Discard: |======| NP -> UCP NN [4.21514e-05]
#   Discard: |======| NP-SBJ-1 -> NP PP VP [0.00097371]
#   Discard: |======| NP-SBJ-1 -> NP PP VP [0.00097371]
#   Discard: |======| NP-SBJ-1 -> NP PP VP [0.00097371]
#   Discard: |======| NP-SBJ-1 -> NP PP VP [0.00097371]
#   Discard: |======| NP-SBJ-1 -> NP PP VP [0.00097371]
#   Discard: |======| NP-SBJ-1 -> NP PP VP [0.00097371]
#    Insert: |======| SQ -> NP-SBJ VP [0.176471]
#   Discard: |======| SQ -> NP-SBJ VP [0.176471]
#    Insert: |======| SQ -> NP-SBJ VP [0.176471]
#   Discard: |======| SQ -> NP-SBJ VP [0.176471]
#   Discard: |======| SQ -> NP-SBJ VP [0.176471]
#   Discard: |======| NP-SBJ-2 -> NP PP-LOC PP [0.0030303]
#   Discard: |======| NP-SBJ -> NP PP-TMP PP [0.000130856]
#    Insert: |======| PP-CLR -> PP PP [0.00326264]
#    Insert: |======| PP-CLR -> PP PP [0.00326264]
#   Discard: |======| PP-CLR -> PP PP [0.00326264]
#   Discard: |======| NP -> NP NP-TMP PP [0.000126454]
#   Discard: |======| NP -> NP NP-TMP PP [0.000126454]
#   Discard: |======| NP -> NP NP-TMP PP [0.000126454]
#   Discard: |======| NP -> NP CD NN [8.43028e-05]
#    Insert: |======| PP-PRD-LOC -> ADVP IN NP [0.2]
#   Discard: |======| S-1 -> PRN NP-SBJ VP [0.0235294]
#   Discard: |======| S-1 -> PRN NP-SBJ VP [0.0235294]
#   Discard: |======| S-1 -> PRN NP-SBJ VP [0.0235294]
#   Discard: |======| S-1 -> PRN NP-SBJ VP [0.0235294]
#   Discard: |======| S-1 -> PRN NP-SBJ VP [0.0235294]
#   Discard: |======| S-1 -> PRN NP-SBJ VP [0.0235294]
#   Discard: |======| S -> NP-SBJ-76 VP [0.000115607]
#   Discard: |======| S -> NP-SBJ-78 VP [0.000231214]
#   Discard: |======| S -> NP-SBJ-78 VP [0.000231214]
#   Discard: |======| S -> NP-SBJ-78 VP [0.000231214]
#   Discard: |======| S -> NP-SBJ-78 VP [0.000231214]
#    Insert: |======| NP-TTL -> NP PP [0.0285714]
#   Discard: |======| NP-TTL -> NP PP [0.0285714]
#    Insert: |======| NP-TTL -> NP PP [0.0285714]
#   Discard: |======| NP-TTL -> NP PP [0.0285714]
#    Insert: |======| PP-TTL -> NNP NP [1.0]
#   Discard: |======| NP-PRD -> DT ADJP NN [0.00892857]
#   Discard: |======| NP-PRD -> NP PP SBAR [0.0125]
#    Insert: |======| NP-SBJ-80 -> NP PP [0.5]
#   Discard: |======| NP-SBJ-80 -> NP PP [0.5]
#    Insert: |======| NP-SBJ-80 -> NP PP [0.5]
#   Discard: |======| NP-SBJ-80 -> NP PP [0.5]
#   Discard: |======| NP -> NP SBAR-TMP [0.000168606]
#   Discard: |======| S -> NP-SBJ-81 VP [0.000231214]
#   Discard: |======| S-TPC-2 -> NP-SBJ ADVP VP [0.0117647]
#   Discard: |======| S-TPC-2 -> NP-SBJ ADVP VP [0.0117647]
#   Discard: |======| S-TPC-2 -> NP-SBJ ADVP VP [0.0117647]
#   Discard: |======| S-TPC-2 -> NP-SBJ ADVP VP [0.0117647]
#   Discard: |======| S-TPC-2 -> NP-SBJ ADVP VP [0.0117647]
#   Discard: |======| S-TPC-2 -> NP-SBJ ADVP VP [0.0117647]
#   Discard: |======| S-TPC-2 -> NP-SBJ ADVP VP [0.0117647]
#   Discard: |======| NP-LGS -> NP JJ NN [0.00854701]
#    Insert: |======| PP-LOC -> NNP NP [0.000839631]
#   Discard: |======| NP-SBJ-2 -> NP PRN [0.00606061]
#   Discard: |======| NP-SBJ-2 -> NP PRN [0.00606061]
#   Discard: |======| NP-SBJ-2 -> NP PRN [0.00606061]
#   Discard: |======| NP-SBJ-2 -> NP PRN [0.00606061]
#   Discard: |======| S -> NP-SBJ-84 VP [0.000115607]
#   Discard: |======| S -> NP-SBJ-84 VP [0.000115607]
#   Discard: |======| S -> NP-SBJ-84 VP [0.000115607]
#   Discard: |======| NP-PRD -> NP PP PP-LOC [0.00357143]
#   Discard: |======| NP-PRD -> NP PP PP-LOC [0.00357143]
#   Discard: |======| NP-PRD -> NP PP PP-LOC [0.00357143]
#   Discard: |======| NP-SBJ-2 -> DT ADJP NN [0.0030303]
#   Discard: |======| S-TPC-1 -> NP-SBJ-87 VP [0.0044843]
#   Discard: |======| S-TPC-1 -> NP-SBJ-87 VP [0.0044843]
#   Discard: |======| S-TPC-1 -> NP-SBJ-87 VP [0.0044843]
#    Insert: |======| NP-SBJ-87 -> NP PP [1.0]
#   Discard: |======| NP-SBJ-87 -> NP PP [1.0]
#    Insert: |======| NP-SBJ-87 -> NP PP [1.0]
#   Discard: |======| NP-SBJ-87 -> NP PP [1.0]
#    Insert: |======| S-TMP -> NP-SBJ VP PP-TMP [0.5]
#    Insert: |======| S-TMP -> NP-SBJ VP PP-TMP [0.5]
#   Discard: |======| PP-CLR -> ADVP IN NP [0.0040783]
#   Discard: |======| S -> PP-TMP NP-SBJ-2 VP [0.000115607]
#   Discard: |======| VP -> JJ PP-CLR [0.000137836]
#    Insert: |======| NP-SBJ-95 -> NP PP [1.0]
#   Discard: |======| NP-SBJ-95 -> NP PP [1.0]
#    Insert: |======| NP-SBJ-95 -> NP PP [1.0]
#   Discard: |======| NP-SBJ-95 -> NP PP [1.0]
#   Discard: |======| S-ADV -> ADVP NP-SBJ VP [0.0045045]
#   Discard: |======| S-ADV -> ADVP NP-SBJ VP [0.0045045]
#   Discard: |======| S-ADV -> ADVP NP-SBJ VP [0.0045045]
#   Discard: |======| S-ADV -> ADVP NP-SBJ VP [0.0045045]
#   Discard: |======| S-ADV -> ADVP NP-SBJ VP [0.0045045]
#   Discard: |======| S-ADV -> ADVP NP-SBJ VP [0.0045045]
#   Discard: |======| S-ADV -> ADVP NP-SBJ VP [0.0045045]
#   Discard: |======| ADJP-PRD -> JJ NP-TMP PP [0.00166113]
#   Discard: |======| ADJP-PRD -> JJ NP-TMP PP [0.00166113]
#    Insert: |======| PP-PRP -> JJ PP [0.0238095]
#   Discard: |======| NP -> NP ADJP VP [4.21514e-05]
#   Discard: |======| NP -> NP ADJP VP [4.21514e-05]
#   Discard: |======| NP -> NP ADJP VP [4.21514e-05]
#   Discard: |======| NP -> NP ADJP VP [4.21514e-05]
#   Discard: |======| NP -> NP ADJP VP [4.21514e-05]
#   Discard: |======| NP -> NP ADJP VP [4.21514e-05]
#   Discard: |======| NP -> NP ADJP VP [4.21514e-05]
#   Discard: |======| NP -> NP ADJP VP [4.21514e-05]
#   Discard: |======| S -> NP-TMP NP-SBJ VP [0.000115607]
#   Discard: |======| S -> NP-TMP NP-SBJ VP [0.000115607]
#   Discard: |======| S -> NP-TMP NP-SBJ VP [0.000115607]
#   Discard: |======| S -> NP-TMP NP-SBJ VP [0.000115607]
#   Discard: |======| S -> NP-TMP NP-SBJ VP [0.000115607]
#   Discard: |======| S -> NP-TMP NP-SBJ VP [0.000115607]
#   Discard: |======| S -> NP-TMP NP-SBJ VP [0.000115607]
#   Discard: |======| S -> NP-TMP NP-SBJ VP [0.000115607]
#   Discard: |======| S -> NP-TMP NP-SBJ VP [0.000115607]
#   Discard: |======| S -> NP-TMP NP-SBJ VP [0.000115607]
#   Discard: |======| NP -> NP UCP [4.21514e-05]
#   Discard: |======| NP -> NP UCP [4.21514e-05]
#    Insert: |======| UCP -> PP PRN [0.037037]
#   Discard: |======| UCP -> PP PRN [0.037037]
#   Discard: |======| UCP -> PP PRN [0.037037]
#   Discard: |======| PP-DIR -> PP PP NP-ADV-1 [0.002457]
#   Discard: |======| NP-PRD -> NP ADVP [0.00178571]
#   Discard: |======| NP-PRD -> NP ADVP [0.00178571]
#   Discard: |======| NP-PRD -> NP ADVP [0.00178571]
#   Discard: |======| NP-PRD -> NP ADVP [0.00178571]
#   Discard: |======| NP -> NP NP-ADV ADVP [4.21514e-05]
#   Discard: |======| NP -> NP NP-ADV ADVP [4.21514e-05]
#   Discard: |======| NP -> NP NP-ADV ADVP [4.21514e-05]
#   Discard: |======| NP -> NP NP-ADV ADVP [4.21514e-05]
#   Discard: |======| NP -> NP NP-ADV ADVP [4.21514e-05]
#   Discard: |======| S -> NP-SBJ-97 VP [0.000115607]
#   Discard: |======| NP -> NP PP-LOC NP [4.21514e-05]
#   Discard: |======| NP -> NP PP-LOC NP [4.21514e-05]
#   Discard: |======| S -> NP-SBJ-99 VP [0.000115607]
#   Discard: |======| S-PRP -> ADVP NP-SBJ VP [0.0267857]
#   Discard: |======| S-PRP -> ADVP NP-SBJ VP [0.0267857]
#   Discard: |======| S-PRP -> ADVP NP-SBJ VP [0.0267857]
#   Discard: |======| S-PRP -> ADVP NP-SBJ VP [0.0267857]
#   Discard: |======| S-PRP -> ADVP NP-SBJ VP [0.0267857]
#   Discard: |======| S-PRP -> ADVP NP-SBJ VP [0.0267857]
#   Discard: |======| S-PRP -> ADVP NP-SBJ VP [0.0267857]
#   Discard: |======| S -> NP-SBJ PP-LOC-PRD [0.000115607]
#   Discard: |======| S-ADV -> NP-SBJ ADVP VP [0.027027]
#   Discard: |======| S-ADV -> NP-SBJ ADVP VP [0.027027]
#   Discard: |======| S-ADV -> NP-SBJ ADVP VP [0.027027]
#   Discard: |======| S-ADV -> NP-SBJ ADVP VP [0.027027]
#   Discard: |======| S-ADV -> NP-SBJ ADVP VP [0.027027]
#   Discard: |======| S-ADV -> NP-SBJ ADVP VP [0.027027]
#   Discard: |======| S-ADV -> NP-SBJ ADVP VP [0.027027]
#   Discard: |======| NP -> NP PP PRN [0.000168606]
#   Discard: |======| NP -> NP PP PRN [0.000168606]
#   Discard: |======| NP -> NP PP PRN [0.000168606]
#   Discard: |======| S -> NP-SBJ-103 VP [0.000115607]
#    Insert: |======| NP-SBJ-103 -> NP SBAR [1.0]
#   Discard: |======| NP -> NP NP PP [4.21514e-05]
#   Discard: |======| NP -> NP NP PP [4.21514e-05]
#   Discard: |======| NP -> NP NP PP [4.21514e-05]
#   Discard: |======| NP -> NP NP PP [4.21514e-05]
#   Discard: |======| NP -> NP NP PP [4.21514e-05]
#   Discard: |======| NP -> NP NP PP [4.21514e-05]
#    Insert: |======| S-NOM -> NP-SBJ PP-LOC-PRD [0.00319489]
#   Discard: |======| S -> PP NP-SBJ VP [0.000578035]
#   Discard: |======| S -> PP NP-SBJ VP [0.000578035]
#   Discard: |======| S -> PP NP-SBJ VP [0.000578035]
#   Discard: |======| S -> PP NP-SBJ VP [0.000578035]
#   Discard: |======| S -> PP NP-SBJ VP [0.000578035]
#   Discard: |======| S -> PP NP-SBJ VP [0.000578035]
#   Discard: |======| NP-PRD -> NP X [0.00178571]
#   Discard: |======| NP-PRD -> NP X [0.00178571]
#   Discard: |======| NP-PRD -> NP X [0.00178571]
#   Discard: |======| NP-PRD -> NP X [0.00178571]
#   Discard: |======| NP-PRD -> NP X [0.00178571]
#   Discard: |======| NP -> NP PP-LOC PP [0.000168606]
#   Discard: |======| S -> NP-SBJ-113 VP [0.000115607]
#   Discard: |======| S -> NP-SBJ-113 VP [0.000115607]
#   Discard: |======| S -> NP-SBJ-113 VP [0.000115607]
#    Insert: |======| NP-SBJ-113 -> NP PP [1.0]
#   Discard: |======| NP-SBJ-113 -> NP PP [1.0]
#    Insert: |======| NP-SBJ-113 -> NP PP [1.0]
#   Discard: |======| NP-SBJ-113 -> NP PP [1.0]
#   Discard: |======| NP-LGS -> NP VP [0.0213675]
#   Discard: |======| NP-LGS -> NP VP [0.0213675]
#   Discard: |======| NP-LGS -> NP VP [0.0213675]
#   Discard: |======| NP-LGS -> NP VP [0.0213675]
#   Discard: |======| NP-LGS -> NP VP [0.0213675]
#   Discard: |======| NP-SBJ -> NP NP-ADV [0.000130856]
#   Discard: |======| NP-SBJ -> NP NP-ADV [0.000130856]
#   Discard: |======| NP-SBJ -> NP NP-ADV [0.000130856]
#   Discard: |======| NP-SBJ -> NP NP-ADV [0.000130856]
#   Discard: |======| NP-SBJ -> NP NP-ADV [0.000130856]
#    Insert: |======| NP-EXT -> NP NP-ADV [0.0454545]
#    Insert: |======| NP-EXT -> NP NP-ADV [0.0454545]
#   Discard: |======| NP-EXT -> NP NP-ADV [0.0454545]
#   Discard: |======| NP-EXT -> NP NP-ADV [0.0454545]
#   Discard: |======| NP-EXT -> NP NP-ADV [0.0454545]
#   Discard: |======| S -> NP-SBJ-114 VP [0.000115607]
#    Insert: |======| NP-SBJ-114 -> NP NN [1.0]
#   Discard: |======| S -> NP-SBJ-115 VP [0.000115607]
#   Discard: |======| NP-SBJ -> NP PP-LOC PP [0.000130856]
#   Discard: |======| NP-SBJ -> NP-1 VP [0.000130856]
#   Discard: |======| NP-SBJ -> NP-1 VP [0.000130856]
#   Discard: |======| NP-SBJ -> NP-1 VP [0.000130856]
#   Discard: |======| NP-SBJ -> NP-1 VP [0.000130856]
#   Discard: |======| NP-SBJ -> NP-1 VP [0.000130856]
#   Discard: |======| NP -> NP ADJP JJ NN [8.43028e-05]
#   Discard: |======| NP -> NP ADJP JJ NN [8.43028e-05]
#   Discard: |======| NP -> NP ADJP JJ NN [8.43028e-05]
#   Discard: |======| NP-LGS -> NP PP-LOC PP [0.0042735]
#   Discard: |======| NP -> NP VP PP-LOC [4.21514e-05]
#   Discard: |======| NP -> NP VP PP-LOC [4.21514e-05]
#   Discard: |======| NP -> NP VP PP-LOC [4.21514e-05]
#   Discard: |======| NP -> NP VP PP-LOC [4.21514e-05]
#   Discard: |======| NP-1 -> NP NN [0.0208333]
#   Discard: |======| NP -> NP PP ADVP-TMP [0.000126454]
#   Discard: |======| NP -> NP PP ADVP-TMP [0.000126454]
#   Discard: |======| NP -> NP PP ADVP-TMP [0.000126454]
#   Discard: |======| NP -> NP PP ADVP-TMP [0.000126454]
#   Discard: |======| S-TPC-1 -> S-SBJ VP [0.0044843]
#   Discard: |======| S-TPC-1 -> S-SBJ VP [0.0044843]
#   Discard: |======| S-TPC-1 -> S-SBJ VP [0.0044843]
#   Discard: |======| S-TPC-1 -> S-SBJ VP [0.0044843]
#   Discard: |======| S-SBJ -> NP-SBJ VP [0.333333]
#   Discard: |======| S-SBJ -> NP-SBJ VP [0.333333]
#    Insert: |======| S-SBJ -> NP-SBJ VP [0.333333]
#   Discard: |======| S-SBJ -> NP-SBJ VP [0.333333]
#   Discard: |======| S-SBJ -> NP-SBJ VP [0.333333]
#   Discard: |======| NP-SBJ -> DT NAC NN [0.000130856]
#   Discard: |======| SBAR-NOM -> WHNP-188 S [0.0185185]
#    Insert: |======| WHNP-188 -> WHNP ADVP [1.0]
#   Discard: |======| S-PRP -> ADVP NP-SBJ-2 VP [0.00892857]
#   Discard: |======| S-PRP -> ADVP NP-SBJ-2 VP [0.00892857]
#   Discard: |======| S-PRP -> ADVP NP-SBJ-2 VP [0.00892857]
#   Discard: |======| S-PRP -> ADVP NP-SBJ-2 VP [0.00892857]
#   Discard: |======| S-PRP -> ADVP NP-SBJ-2 VP [0.00892857]
#   Discard: |======| S-PRP -> ADVP NP-SBJ-2 VP [0.00892857]
#   Discard: |======| S-TPC-1 -> S IN S [0.0044843]
#   Discard: |======| S-ADV -> NP-SBJ ADVP-TMP VP [0.0045045]
#   Discard: |======| S-ADV -> NP-SBJ ADVP-TMP VP [0.0045045]
#   Discard: |======| S-ADV -> NP-SBJ ADVP-TMP VP [0.0045045]
#   Discard: |======| S-ADV -> NP-SBJ ADVP-TMP VP [0.0045045]
#   Discard: |======| S-ADV -> NP-SBJ ADVP-TMP VP [0.0045045]
#   Discard: |======| S-ADV -> NP-SBJ ADVP-TMP VP [0.0045045]
#   Discard: |======| S-ADV -> NP-SBJ ADVP-TMP VP [0.0045045]
#   Discard: |======| S-ADV -> NP-SBJ ADVP-TMP VP [0.0045045]
#   Discard: |======| S -> NP-SBJ VP PP-TMP [0.000115607]
#   Discard: |======| S -> NP-SBJ VP PP-TMP [0.000115607]
#    Insert: |======| NP-2 -> NP PP-DIR [0.0238095]
#    Insert: |======| NP-2 -> NP PP-DIR [0.0238095]
#    Insert: |======| NP-SBJ-118 -> NP SBAR [1.0]
#    Insert: |======| WHNP-1 -> NP WHPP [0.0058309]
#    Insert: |======| NP-SBJ-119 -> NP PP [1.0]
#   Discard: |======| NP-SBJ-119 -> NP PP [1.0]
#    Insert: |======| NP-SBJ-119 -> NP PP [1.0]
#   Discard: |======| NP-SBJ-119 -> NP PP [1.0]
#   Discard: |======| ADJP -> ADVP JJ PP [0.0014556]
#    Insert: |======| NP-SBJ-121 -> NP PP [1.0]
#   Discard: |======| NP-SBJ-121 -> NP PP [1.0]
#    Insert: |======| NP-SBJ-121 -> NP PP [1.0]
#   Discard: |======| NP-SBJ-121 -> NP PP [1.0]
#   Discard: |======| NP -> NP RB NP [4.21514e-05]
#   Discard: |======| PP-MNR -> ADVP IN NP [0.027972]
#   Discard: |======| NP -> NP ADVP PP [8.43028e-05]
#   Discard: |======| NP -> NP ADVP PP [8.43028e-05]
#   Discard: |======| NP -> NP ADVP PP [8.43028e-05]
#   Discard: |======| NP -> NP ADVP PP [8.43028e-05]
#   Discard: |======| VP -> JJ VP [6.8918e-05]
#   Discard: |======| S -> NP-SBJ-122 VP [0.000115607]
#   Discard: |======| S -> S-NOM-SBJ ADJP-PRD [0.000115607]
#   Discard: |======| S -> S-NOM-SBJ ADJP-PRD [0.000115607]
#   Discard: |======| S -> S-NOM-SBJ ADJP-PRD [0.000115607]
#   Discard: |======| S -> S-NOM-SBJ ADJP-PRD [0.000115607]
#   Discard: |======| NP-ADV -> NP SBAR [0.0248756]
#   Discard: |======| NP-ADV -> DT ADJP [0.00497512]
#   Discard: |======| NP-EXT -> NP PP [0.00757576]
#   Discard: |======| NP-EXT -> NP PP [0.00757576]
#    Insert: |======| NP-EXT -> NP PP [0.00757576]
#   Discard: |======| NP-EXT -> NP PP [0.00757576]
#   Discard: |======| S -> NP-SBJ-128 VP [0.000115607]
#   Discard: |======| S -> NP-SBJ-128 VP [0.000115607]
#   Discard: |======| S -> NP-SBJ-128 VP [0.000115607]
#    Insert: |======| NP-SBJ-128 -> NP PP [1.0]
#   Discard: |======| NP-SBJ-128 -> NP PP [1.0]
#    Insert: |======| NP-SBJ-128 -> NP PP [1.0]
#   Discard: |======| NP-SBJ-128 -> NP PP [1.0]
#    Insert: |======| NP-SBJ-130 -> NP PP [1.0]
#   Discard: |======| NP-SBJ-130 -> NP PP [1.0]
#    Insert: |======| NP-SBJ-130 -> NP PP [1.0]
#   Discard: |======| NP-SBJ-130 -> NP PP [1.0]
#   Discard: |======| S-NOM -> NP-SBJ RB VP [0.00638978]
#    Insert: |======| NP-SBJ-132 -> ADJP JJ NN [1.0]
#   Discard: |======| NP-SBJ -> NP PP NP [0.000130856]
#   Discard: |======| NP-SBJ -> NP PP NP [0.000130856]
#   Discard: |======| NP-SBJ -> NP PP NP [0.000130856]
#   Discard: |======| NP-SBJ -> NP PP NP [0.000130856]
#   Discard: |======| NP-SBJ -> NP PP NP [0.000130856]
#   Discard: |======| NP-SBJ -> NP PP NP [0.000130856]
#   Discard: |======| NP-SBJ -> NP ADVP-LOC [0.000523423]
#   Discard: |======| NP-SBJ -> NP ADVP-LOC [0.000523423]
#   Discard: |======| NP-SBJ -> NP ADVP-LOC [0.000523423]
#   Discard: |======| PP-DIR -> PP PP [0.002457]
#    Insert: |======| PP-DIR -> PP PP [0.002457]
#   Discard: |======| PP-DIR -> PP PP [0.002457]
#    Insert: |======| NP-SBJ-136 -> NP PP [1.0]
#   Discard: |======| NP-SBJ-136 -> NP PP [1.0]
#    Insert: |======| NP-SBJ-136 -> NP PP [1.0]
#   Discard: |======| NP-SBJ-136 -> NP PP [1.0]
#   Discard: |======| NP -> NP PRN VP [4.21514e-05]
#   Discard: |======| NP -> NP PRN VP [4.21514e-05]
#   Discard: |======| NP -> NP PRN VP [4.21514e-05]
#   Discard: |======| NP -> NP PRN VP [4.21514e-05]
#   Discard: |======| NP -> NP PRN VP [4.21514e-05]
#   Discard: |======| NP -> NP PRN VP [4.21514e-05]
#   Discard: |======| S-ADV -> NP-SBJ ADVP-LOC-PRD PP [0.0045045]
#   Discard: |======| S-ADV -> NP-SBJ ADVP-LOC-PRD PP [0.0045045]
#   Discard: |======| S-ADV -> NP-SBJ ADVP-LOC-PRD PP [0.0045045]
#    Insert: |======| SBAR-2 -> WHNP-1 S [0.25]
#   Discard: |======| SBAR-2 -> WHNP-1 S [0.25]
#   Discard: |======| S-CLR -> NP-SBJ ADJP-PRD [0.032967]
#   Discard: |======| S-CLR -> NP-SBJ ADJP-PRD [0.032967]
#   Discard: |======| S-CLR -> NP-SBJ ADJP-PRD [0.032967]
#   Discard: |======| S-CLR -> NP-SBJ ADJP-PRD [0.032967]
#   Discard: |======| S-CLR -> NP-SBJ ADJP-PRD [0.032967]
#    Insert: |======| PP-LOC-CLR -> JJ PP [0.0166667]
#   Discard: |======| S -> NP-SBJ-139 VP [0.000115607]
#   Discard: |======| S -> NP-SBJ-139 VP [0.000115607]
#   Discard: |======| S -> NP-SBJ-139 VP [0.000115607]
#   Discard: |======| S -> NP-SBJ-139 VP [0.000115607]
#    Insert: |======| NP-SBJ-139 -> NP NP [1.0]
#    Insert: |======| NP-SBJ-139 -> NP NP [1.0]
#   Discard: |======| NP-SBJ-139 -> NP NP [1.0]
#   Discard: |======| NP-SBJ-139 -> NP NP [1.0]
#   Discard: |======| NP-SBJ-139 -> NP NP [1.0]
#    Insert: |======| NP-TTL -> NP PP-LOC [0.0285714]
#   Discard: |======| NP-TTL -> NP PP-LOC [0.0285714]
#   Discard: |======| NP-PRD -> NP PP PP [0.00892857]
#   Discard: |======| NP-PRD -> NP PP PP [0.00892857]
#   Discard: |======| NP-PRD -> NP PP PP [0.00892857]
#   Discard: |======| NP -> NP ADVP-LOC PP [4.21514e-05]
#   Discard: |======| NP -> NP ADVP-LOC PP [4.21514e-05]
#   Discard: |======| NP -> NP ADVP-LOC PP [4.21514e-05]
#   Discard: |======| NP-PRD -> NP PRN SBAR [0.00178571]
#   Discard: |======| PP-PRD -> NP-ADV IN NP [0.011236]
#    Insert: |======| NP-SBJ-142 -> NP PP [1.0]
#   Discard: |======| NP-SBJ-142 -> NP PP [1.0]
#    Insert: |======| NP-SBJ-142 -> NP PP [1.0]
#   Discard: |======| NP-SBJ-142 -> NP PP [1.0]
#   Discard: |======| WHNP-1 -> WHNP PP [0.0058309]
#   Discard: |======| S -> NP-SBJ ADJP-PRD NP-TMP [0.000115607]
#   Discard: |======| S -> NP-SBJ ADJP-PRD NP-TMP [0.000115607]
#   Discard: |======| S -> NP-SBJ ADJP-PRD NP-TMP [0.000115607]
#   Discard: |======| S -> NP-SBJ ADJP-PRD NP-TMP [0.000115607]
#   Discard: |======| S -> NP-SBJ ADJP-PRD NP-TMP [0.000115607]
#   Discard: |======| S -> NP-SBJ ADJP-PRD NP-TMP [0.000115607]
#   Discard: |======| S -> NP-SBJ ADJP-PRD NP-TMP [0.000115607]
#   Discard: |======| S -> NP-SBJ ADJP-PRD NP-TMP [0.000115607]
#   Discard: |======| S-NOM -> NP-SBJ-4 VP [0.00319489]
#   Discard: |======| S-NOM -> NP-SBJ-4 VP [0.00319489]
#   Discard: |======| S-NOM -> NP-SBJ-4 VP [0.00319489]
#   Discard: |======| S-NOM -> NP-SBJ-4 VP [0.00319489]
#   Discard: |======| NP-PRD -> NP PP PP-TMP [0.00178571]
#   Discard: |======| S -> ADJP-PRD SBAR-SBJ [0.000115607]
#   Discard: |======| NP-PRD -> NP PRN PP [0.00357143]
#   Discard: |======| NP-PRD -> NP PRN PP [0.00357143]
#   Discard: |======| NP-PRD -> NP PRN PP [0.00357143]
#    Insert: |======| S-TTL -> NP-SBJ VP [1.0]
#   Discard: |======| S-TTL -> NP-SBJ VP [1.0]
#    Insert: |======| S-TTL -> NP-SBJ VP [1.0]
#   Discard: |======| S-TTL -> NP-SBJ VP [1.0]
#   Discard: |======| S-TTL -> NP-SBJ VP [1.0]
#   Discard: |======| NP-SBJ-1 -> NP NP [0.00194742]
#   Discard: |======| NP-SBJ-1 -> NP NP [0.00194742]
#   Discard: |======| NP-SBJ-1 -> NP NP [0.00194742]
#   Discard: |======| NP-SBJ-1 -> NP NP [0.00194742]
#   Discard: |======| NP-SBJ-1 -> NP NP [0.00194742]
#   Discard: |======| S -> NP-SBJ-151 VP [0.000115607]
#   Discard: |======| S-NOM -> NP-SBJ ADVP VP [0.00638978]
#   Discard: |======| S-NOM -> NP-SBJ ADVP VP [0.00638978]
#   Discard: |======| S-NOM -> NP-SBJ ADVP VP [0.00638978]
#   Discard: |======| S-NOM -> NP-SBJ ADVP VP [0.00638978]
#   Discard: |======| S-NOM -> NP-SBJ ADVP VP [0.00638978]
#   Discard: |======| S-NOM -> NP-SBJ ADVP VP [0.00638978]
#   Discard: |======| S-NOM -> NP-SBJ ADVP VP [0.00638978]
#    Insert: |======| NP-SBJ-157 -> NP PP [1.0]
#   Discard: |======| NP-SBJ-157 -> NP PP [1.0]
#    Insert: |======| NP-SBJ-157 -> NP PP [1.0]
#   Discard: |======| NP-SBJ-157 -> NP PP [1.0]
#   Discard: |======| NP -> ADVP-TMP NN [4.21514e-05]
#   Discard: |======| FRAG -> NP-SBJ NP [0.336735]
#    Insert: |======| FRAG -> NP-SBJ NP [0.336735]
#   Discard: |======| FRAG -> NP-SBJ NP [0.336735]
#   Discard: |======| FRAG -> NP-SBJ NP [0.336735]
#   Discard: |======| FRAG -> NP-SBJ NP [0.336735]
#   Discard: |======| FRAG -> NP-SBJ-1 VP [0.0102041]
#   Discard: |======| FRAG -> NP-SBJ-1 VP [0.0102041]
#   Discard: |======| FRAG -> NP-SBJ-1 VP [0.0102041]
#   Discard: |======| FRAG -> NP-SBJ-1 VP [0.0102041]
#   Discard: |======| FRAG -> NP-SBJ-1 VP [0.0102041]
#   Discard: |======| FRAG -> NP-SBJ-2 VP [0.0102041]
#   Discard: |======| FRAG -> NP-SBJ-2 VP [0.0102041]
#   Discard: |======| FRAG -> NP-SBJ-2 VP [0.0102041]
#   Discard: |======| FRAG -> NP-SBJ-2 VP [0.0102041]
#   Discard: |======| FRAG -> NP-SBJ-2 VP [0.0102041]
#   Discard: |======| NP-SBJ-1 -> NP FRAG [0.00097371]
#   Discard: |======| NP-SBJ-1 -> NP FRAG [0.00097371]
#   Discard: |======| NP-SBJ-1 -> NP FRAG [0.00097371]
#   Discard: |======| NP-SBJ-1 -> NP FRAG [0.00097371]
#   Discard: |======| NP-SBJ-1 -> NP FRAG [0.00097371]
#   Discard: |======| FRAG -> NP-SBJ-3 VP [0.0102041]
#   Discard: |======| FRAG -> NP-SBJ-3 VP [0.0102041]
#   Discard: |======| FRAG -> NP-SBJ-3 VP [0.0102041]
#   Discard: |======| FRAG -> NP-SBJ-3 VP [0.0102041]
#   Discard: |======| FRAG -> NP-SBJ-3 VP [0.0102041]
#   Discard: |======| FRAG -> NP-SBJ-7 VP [0.0102041]
#   Discard: |======| FRAG -> NP-SBJ-7 VP [0.0102041]
#   Discard: |======| FRAG -> NP-SBJ-7 VP [0.0102041]
#   Discard: |======| NP-SBJ-3 -> NP FRAG [0.00925926]
#   Discard: |======| NP-SBJ-3 -> NP FRAG [0.00925926]
#   Discard: |======| NP-SBJ-3 -> NP FRAG [0.00925926]
#   Discard: |======| NP-SBJ-3 -> NP FRAG [0.00925926]
#   Discard: |======| NP-SBJ-3 -> NP FRAG [0.00925926]
#   Discard: |======| NP -> NP PP PP-LOC PP [4.21514e-05]
#   Discard: |======| S-TPC-2 -> NP-SBJ-1 ADVP-TMP VP [0.0117647]
#   Discard: |======| S-TPC-2 -> NP-SBJ-1 ADVP-TMP VP [0.0117647]
#   Discard: |======| S-TPC-2 -> NP-SBJ-1 ADVP-TMP VP [0.0117647]
#   Discard: |======| S-TPC-2 -> NP-SBJ-1 ADVP-TMP VP [0.0117647]
#   Discard: |======| S-TPC-2 -> NP-SBJ-1 ADVP-TMP VP [0.0117647]
#   Discard: |======| S-TPC-2 -> NP-SBJ-1 ADVP-TMP VP [0.0117647]
#   Discard: |======| S-TPC-2 -> NP-SBJ-1 ADVP-TMP VP [0.0117647]
#   Discard: |======| S-TPC-2 -> NP-SBJ-1 ADVP-TMP VP [0.0117647]
#   Discard: |======| SBAR -> WHNP S [0.000424628]
#    Insert: |======| S-PRP-CLR -> NP-SBJ VP [0.8]
#   Discard: |======| S-PRP-CLR -> NP-SBJ VP [0.8]
#    Insert: |======| S-PRP-CLR -> NP-SBJ VP [0.8]
#   Discard: |======| S-PRP-CLR -> NP-SBJ VP [0.8]
#   Discard: |======| S-PRP-CLR -> NP-SBJ VP [0.8]
#    Insert: |======| NP-SBJ-161 -> NP PP [1.0]
#   Discard: |======| NP-SBJ-161 -> NP PP [1.0]
#    Insert: |======| NP-SBJ-161 -> NP PP [1.0]
#   Discard: |======| NP-SBJ-161 -> NP PP [1.0]
#   Discard: |======| NP -> NP PP SBAR-TMP [0.000126454]
#   Discard: |======| S-ADV -> NP-SBJ ADVP-TMP ADJP-PRD [0.0045045]
#   Discard: |======| S-ADV -> NP-SBJ ADVP-TMP ADJP-PRD [0.0045045]
#   Discard: |======| S-ADV -> NP-SBJ ADVP-TMP ADJP-PRD [0.0045045]
#   Discard: |======| S-ADV -> NP-SBJ ADVP-TMP ADJP-PRD [0.0045045]
#   Discard: |======| S-ADV -> NP-SBJ ADVP-TMP ADJP-PRD [0.0045045]
#   Discard: |======| S-ADV -> NP-SBJ ADVP-TMP ADJP-PRD [0.0045045]
#   Discard: |======| S-ADV -> NP-SBJ ADVP-TMP ADJP-PRD [0.0045045]
#   Discard: |======| S-ADV -> NP-SBJ ADVP-TMP ADJP-PRD [0.0045045]
#   Discard: |======| NP -> NP JJ ADJP NN [4.21514e-05]
#   Discard: |======| S-2 -> NP-SBJ-1 VP [0.075]
#   Discard: |======| S-2 -> NP-SBJ-1 VP [0.075]
#   Discard: |======| S-2 -> NP-SBJ-1 VP [0.075]
#   Discard: |======| S-2 -> NP-SBJ-1 VP [0.075]
#   Discard: |======| S-2 -> NP-SBJ-1 VP [0.075]
#   Discard: |======| NP-SBJ-2 -> DT NN S [0.0030303]
#   Discard: |======| S -> NP-SBJ VP ADVP-TMP [0.000231214]
#   Discard: |======| S -> NP-SBJ VP ADVP-TMP [0.000231214]
#   Discard: |======| S -> NP-SBJ VP ADVP-TMP [0.000231214]
#   Discard: |======| S -> NP-SBJ VP ADVP-TMP [0.000231214]
#   Discard: |======| S -> NP-SBJ VP ADVP-TMP [0.000231214]
#   Discard: |======| S -> NP-SBJ VP ADVP-TMP [0.000231214]
#    Insert: |======| PP-PRD -> ADJP IN NP [0.011236]
#   Discard: |======| NP-PRD -> NP PP-LOC PP [0.00535714]
#   Discard: |======| NP-SBJ-7 -> NP PP [0.25]
#   Discard: |======| NP-SBJ-7 -> NP PP [0.25]
#   Discard: |======| NP-SBJ-7 -> NP PP [0.25]
#   Discard: |======| NP-SBJ-7 -> NP PP [0.25]
#   Discard: |======| NP -> NP PP-CLR PP [4.21514e-05]
#   Discard: |======| NP -> NP PP-CLR PP [4.21514e-05]
#   Discard: |======| S -> NP-SBJ-9 VP [0.000115607]
#   Discard: |======| S -> NP-SBJ-9 VP [0.000115607]
#   Discard: |======| S -> NP-SBJ-9 VP [0.000115607]
#    Insert: |======| NP-SBJ-9 -> NP PP [0.5]
#   Discard: |======| NP-SBJ-9 -> NP PP [0.5]
#    Insert: |======| NP-SBJ-9 -> NP PP [0.5]
#   Discard: |======| NP-SBJ-9 -> NP PP [0.5]
#   Discard: |======| NP-ADV -> NP NP-ADV [0.0149254]
#   Discard: |======| NP-ADV -> NP NP-ADV [0.0149254]
#   Discard: |======| NP-ADV -> NP NP-ADV [0.0149254]
#   Discard: |======| NP-ADV -> NP NP-ADV [0.0149254]
#   Discard: |======| NP-ADV -> NP NP-ADV [0.0149254]
#   Discard: |======| S -> NP-SBJ-10 VP [0.000115607]
#   Discard: |======| ADJP-PRD -> ADJP S [0.00498339]
#   Discard: |======| ADJP-PRD -> ADJP S [0.00498339]
#   Discard: |======| ADJP-PRD -> ADJP S [0.00498339]
#   Discard: |======| ADJP-PRD -> ADJP S [0.00498339]
#   Discard: |======| NP-SBJ -> DT ADJP NN [0.000523423]
#    Insert: |======| S-HLN -> NP-SBJ VP [0.266667]
#   Discard: |======| S-HLN -> NP-SBJ VP [0.266667]
#    Insert: |======| S-HLN -> NP-SBJ VP [0.266667]
#   Discard: |======| S-HLN -> NP-SBJ VP [0.266667]
#   Discard: |======| S-HLN -> NP-SBJ VP [0.266667]
#   Discard: |======| S -> S-NOM-SBJ ADVP VP [0.000231214]
#   Discard: |======| S -> S-NOM-SBJ ADVP VP [0.000231214]
#   Discard: |======| S -> S-NOM-SBJ ADVP VP [0.000231214]
#   Discard: |======| S -> S-NOM-SBJ ADVP VP [0.000231214]
#   Discard: |======| SINV -> ADVP VP NP-SBJ [0.005]
#   Discard: |======| SINV -> ADVP VP NP-SBJ [0.005]
#   Discard: |======| SINV -> ADVP VP NP-SBJ [0.005]
#   Discard: |======| SINV -> ADVP VP NP-SBJ [0.005]
#   Discard: |======| SINV -> ADVP VP NP-SBJ [0.005]
#   Discard: |======| SINV -> ADVP VP NP-SBJ [0.005]
#   Discard: |======| SINV -> ADVP VP NP-SBJ [0.005]
#   Discard: |======| S-NOM -> NP-SBJ ADVP-TMP VP [0.00319489]
#   Discard: |======| S-NOM -> NP-SBJ ADVP-TMP VP [0.00319489]
#   Discard: |======| S-NOM -> NP-SBJ ADVP-TMP VP [0.00319489]
#   Discard: |======| S-NOM -> NP-SBJ ADVP-TMP VP [0.00319489]
#   Discard: |======| S-NOM -> NP-SBJ ADVP-TMP VP [0.00319489]
#   Discard: |======| S-NOM -> NP-SBJ ADVP-TMP VP [0.00319489]
#   Discard: |======| S-NOM -> NP-SBJ ADVP-TMP VP [0.00319489]
#   Discard: |======| S-NOM -> NP-SBJ ADVP-TMP VP [0.00319489]
#   Discard: |======| S-HLN -> NP-SBJ-1 VP [0.0666667]
#   Discard: |======| S-HLN -> NP-SBJ-1 VP [0.0666667]
#   Discard: |======| S-HLN -> NP-SBJ-1 VP [0.0666667]
#   Discard: |======| S-HLN -> NP-SBJ-1 VP [0.0666667]
#   Discard: |======| S-HLN -> NP-SBJ-1 VP [0.0666667]
#   Discard: |======| NP-PRD -> DT NAC NN [0.00178571]
#   Discard: |======| S-1 -> ADVP PRN NP-SBJ VP [0.0117647]
#   Discard: |======| S-1 -> ADVP PRN NP-SBJ VP [0.0117647]
#   Discard: |======| S-1 -> ADVP PRN NP-SBJ VP [0.0117647]
#   Discard: |======| NP-SBJ-2 -> NP PP-LOC [0.00606061]
#   Discard: |======| NP-SBJ-2 -> NP PP-LOC [0.00606061]
#   Discard: |======| PP -> ADVP IN NP-LGS [0.000581508]
#   Discard: |======| NP-LGS -> NP PP SBAR [0.0042735]
#   Discard: |======| S -> NP-SBJ-2 ADJP-PRD [0.000115607]
#   Discard: |======| S -> NP-SBJ-2 ADJP-PRD [0.000115607]
#   Discard: |======| S -> NP-SBJ-2 ADJP-PRD [0.000115607]
#   Discard: |======| S -> NP-SBJ-2 ADJP-PRD [0.000115607]
#   Discard: |======| S -> NP-SBJ-2 ADJP-PRD [0.000115607]
#   Discard: |======| NP-SBJ -> NP PP PP-LOC PP [0.000130856]
#   Discard: |======| S -> NP-SBJ-17 VP [0.000115607]
#   Discard: |======| S -> NP-SBJ-17 VP [0.000115607]
#   Discard: |======| S-PRD -> NP-SBJ-18 VP [0.0434783]
#   Discard: |======| S -> NP-SBJ CONJP VP [0.000115607]
#   Discard: |======| S -> NP-SBJ-19 VP [0.000115607]
#   Discard: |======| S -> NP-SBJ-19 VP [0.000115607]
#   Discard: |======| S -> NP-SBJ-19 VP [0.000115607]
#    Insert: |======| NP-SBJ-21 -> NP PP [0.5]
#   Discard: |======| NP-SBJ-21 -> NP PP [0.5]
#    Insert: |======| NP-SBJ-21 -> NP PP [0.5]
#   Discard: |======| NP-SBJ-21 -> NP PP [0.5]
#   Discard: |======| FRAG -> ADVP-TMP ADVP-LOC [0.0102041]
#   Discard: |======| FRAG -> ADVP-TMP ADVP-LOC [0.0102041]
#    Insert: |======| SBARQ -> WHNP-1 SQ [0.04]
#   Discard: |======| SBARQ -> WHNP-1 SQ [0.04]
#   Discard: |======| SBARQ -> WHNP-1 SQ [0.04]
#   Discard: |======| WHNP-1 -> WHNP PP ADJP [0.00291545]
#    Insert: |======| ADJP-2 -> JJ PP [1.0]
#   Discard: |======| S -> NP-SBJ-23 VP [0.000115607]
#   Discard: |======| S -> NP-SBJ-23 VP [0.000115607]
#   Discard: |======| S -> NP-SBJ-23 VP [0.000115607]
#   Discard: |======| S -> NP-SBJ-23 VP [0.000115607]
#   Discard: |======| NP-1 -> NP VP [0.0208333]
#   Discard: |======| NP-1 -> NP VP [0.0208333]
#   Discard: |======| NP-1 -> NP VP [0.0208333]
#   Discard: |======| NP-1 -> NP VP [0.0208333]
#   Discard: |======| NP-1 -> NP VP [0.0208333]
#   Discard: |======| NP-SBJ-2 -> NP VP [0.0030303]
#   Discard: |======| NP-SBJ-2 -> NP VP [0.0030303]
#   Discard: |======| NP-SBJ-2 -> NP VP [0.0030303]
#   Discard: |======| NP-SBJ-2 -> NP VP [0.0030303]
#   Discard: |======| NP-SBJ-2 -> NP VP [0.0030303]
#   Discard: |======| S-TPC-1 -> NP-SBJ-3 VP [0.0044843]
#   Discard: |======| S-TPC-1 -> NP-SBJ-3 VP [0.0044843]
#   Discard: |======| S-TPC-1 -> NP-SBJ-3 VP [0.0044843]
#   Discard: |======| S-TPC-1 -> NP-SBJ-3 VP [0.0044843]
#   Discard: |======| S-TPC-1 -> NP-SBJ-3 VP [0.0044843]
#   Discard: |======| S-PRP -> NP-SBJ-4 VP [0.00892857]
#   Discard: |======| S-PRP -> NP-SBJ-4 VP [0.00892857]
#   Discard: |======| S-PRP -> NP-SBJ-4 VP [0.00892857]
#   Discard: |======| S-PRP -> NP-SBJ-4 VP [0.00892857]
#   Discard: |======| S -> NP-SBJ-32 VP [0.000115607]
#   Discard: |======| NP-2 -> ADVP NP SBAR [0.0238095]
#   Discard: |======| S -> NP-SBJ-34 VP [0.000115607]
#   Discard: |======| S -> NP-SBJ-34 VP [0.000115607]
#   Discard: |======| NP-SBJ -> DT NN S [0.000261712]
#   Discard: |======| NP -> NP PP S [4.21514e-05]
#   Discard: |======| NP -> NP PP S [4.21514e-05]
#   Discard: |======| NP -> NP PP S [4.21514e-05]
#   Discard: |======| ADVP-MNR -> ADVP PRN [0.00404858]
#   Discard: |======| ADVP-MNR -> ADVP PRN [0.00404858]
#   Discard: |======| ADVP-MNR -> ADVP PRN [0.00404858]
#   Discard: |======| PP -> PP ADVP [0.000387672]
#   Discard: |======| PP -> PP ADVP [0.000387672]
#   Discard: |======| PP -> PP ADVP [0.000387672]
#   Discard: |======| S -> NP-SBJ-38 VP [0.000115607]
#   Discard: |======| NP -> NP NP-TMP PP-LOC [4.21514e-05]
#   Discard: |======| NP -> NP NP-TMP PP-LOC [4.21514e-05]
#   Discard: |======| NP -> NNP NP [4.21514e-05]
#   Discard: |======| NP -> NP PP PRN NP [4.21514e-05]
#    Insert: |======| NP-SBJ-44 -> NP PP [0.5]
#   Discard: |======| NP-SBJ-44 -> NP PP [0.5]
#    Insert: |======| NP-SBJ-44 -> NP PP [0.5]
#   Discard: |======| NP-SBJ-44 -> NP PP [0.5]
#   Discard: |======| S -> NP-SBJ-45 VP [0.000115607]
#   Discard: |======| S -> NP-SBJ-46 VP [0.000115607]
#   Discard: |======| NP -> NP NN PRN S [4.21514e-05]
#    Insert: |======| NP-SBJ-50 -> NP PP [0.5]
#   Discard: |======| NP-SBJ-50 -> NP PP [0.5]
#    Insert: |======| NP-SBJ-50 -> NP PP [0.5]
#   Discard: |======| NP-SBJ-50 -> NP PP [0.5]
#   Discard: |======| S -> NP-SBJ-51 VP [0.000115607]
#   Discard: |======| S -> NP-SBJ-51 VP [0.000115607]
#   Discard: |======| S -> NP-SBJ-51 VP [0.000115607]
#   Discard: |======| NP-SBJ -> NP PP PP-LOC [0.000130856]
#   Discard: |======| NP-SBJ -> NP PP PP-LOC [0.000130856]
#   Discard: |======| NP-SBJ -> NP PP PP-LOC [0.000130856]
#    Insert: |======| NP-SBJ-52 -> NP PRN [0.5]
#    Insert: |======| NP-SBJ-52 -> NP PRN [0.5]
#   Discard: |======| NP-SBJ-52 -> NP PRN [0.5]
#   Discard: |======| NP-SBJ-52 -> NP PRN [0.5]
#    Insert: |======| NP-SBJ-53 -> NP PP [0.5]
#   Discard: |======| NP-SBJ-53 -> NP PP [0.5]
#    Insert: |======| NP-SBJ-53 -> NP PP [0.5]
#   Discard: |======| NP-SBJ-53 -> NP PP [0.5]
#   Discard: |======| NP -> NP PP-TMP VP [4.21514e-05]
#   Discard: |======| NP -> NP PP-TMP VP [4.21514e-05]
#   Discard: |======| NP -> NP PP-TMP VP [4.21514e-05]
#   Discard: |======| NP -> NP PP-TMP VP [4.21514e-05]
#   Discard: |======| S-NOM -> NP-SBJ-55 VP [0.00319489]
#   Discard: |======| S -> NP-SBJ-56 VP [0.000115607]
#   Discard: |======| PP -> ADVP IN S-NOM [0.000387672]
#   Discard: |======| NP-2 -> NP PP [0.0238095]
#   Discard: |======| NP-2 -> NP PP [0.0238095]
#    Insert: |======| NP-2 -> NP PP [0.0238095]
#   Discard: |======| NP-2 -> NP PP [0.0238095]
#   Discard: |======| NP-PRD -> NP ADJP PP [0.00357143]
#   Discard: |======| NP-PRD -> NP ADJP PP [0.00357143]
#   Discard: |======| NP-PRD -> NP ADJP PP [0.00357143]
#   Discard: |======| NP-PRD -> NP ADJP PP [0.00357143]
#   Discard: |======| NP-SBJ -> NP PP VP [0.000523423]
#   Discard: |======| NP-SBJ -> NP PP VP [0.000523423]
#   Discard: |======| NP-SBJ -> NP PP VP [0.000523423]
#   Discard: |======| NP-SBJ -> NP PP VP [0.000523423]
#   Discard: |======| NP-SBJ -> NP PP VP [0.000523423]
#   Discard: |======| NP-SBJ -> NP PP VP [0.000523423]
#    Insert: |======| ADJP-ADV -> JJ PP [0.5]
#   Discard: |======| NP -> NP PP PP-PRP [4.21514e-05]
#   Discard: |======| NP -> ADJP DT NN [8.43028e-05]
#   Discard: |======| PP-TMP -> NP-EXT IN NP [0.00119474]
#   Discard: |======| NP-SBJ-1 -> NP VP [0.00584226]
#   Discard: |======| NP-SBJ-1 -> NP VP [0.00584226]
#   Discard: |======| NP-SBJ-1 -> NP VP [0.00584226]
#   Discard: |======| NP-SBJ-1 -> NP VP [0.00584226]
#   Discard: |======| NP-SBJ-1 -> NP VP [0.00584226]
#   Discard: |======| NP -> NP ADJP NP-TMP [4.21514e-05]
#   Discard: |======| NP -> NP ADJP NP-TMP [4.21514e-05]
#   Discard: |======| NP -> NP ADJP NP-TMP [4.21514e-05]
#   Discard: |======| NP -> NP ADJP NP-TMP [4.21514e-05]
#   Discard: |======| NP -> NP ADJP NP-TMP [4.21514e-05]
#   Discard: |======| NP -> NP ADJP NP-TMP [4.21514e-05]
#   Discard: |======| NP -> NP ADJP NP-TMP [4.21514e-05]
#   Discard: |======| NP -> NP ADJP NP-TMP [4.21514e-05]
#    Insert: |======| NP-SBJ-67 -> NP PP [0.5]
#   Discard: |======| NP-SBJ-67 -> NP PP [0.5]
#    Insert: |======| NP-SBJ-67 -> NP PP [0.5]
#   Discard: |======| NP-SBJ-67 -> NP PP [0.5]
#   Discard: |======| NP-SBJ -> NP PP-LOC NP [0.000130856]
#   Discard: |======| NP-SBJ -> NP PP-LOC NP [0.000130856]
#   Discard: |======| NP-PRD -> NP JJ JJ NN [0.00178571]
#   Discard: |======| S -> ADJP-PRD NP-SBJ [0.000115607]
#   Discard: |======| S -> ADJP-PRD NP-SBJ [0.000115607]
#   Discard: |======| S -> ADJP-PRD NP-SBJ [0.000115607]
#   Discard: |======| S -> ADJP-PRD NP-SBJ [0.000115607]
#   Discard: |======| S -> ADJP-PRD NP-SBJ [0.000115607]
#   Discard: |======| NP-SBJ -> NP NP PP-LOC [0.000130856]
#   Discard: |======| NP-SBJ -> NP NP PP-LOC [0.000130856]
#   Discard: |======| NP-SBJ -> NP NP PP-LOC [0.000130856]
#   Discard: |======| NP-SBJ -> NP NP PP-LOC [0.000130856]
#   Discard: |======| NP-SBJ -> NP NP PP-LOC [0.000130856]
#   Discard: |======| S-ADV -> NP-SBJ-2 ADVP VP [0.0045045]
#   Discard: |======| S-ADV -> NP-SBJ-2 ADVP VP [0.0045045]
#   Discard: |======| S-ADV -> NP-SBJ-2 ADVP VP [0.0045045]
#   Discard: |======| S-ADV -> NP-SBJ-2 ADVP VP [0.0045045]
#   Discard: |======| S-ADV -> NP-SBJ-2 ADVP VP [0.0045045]
#   Discard: |======| S-ADV -> NP-SBJ-2 ADVP VP [0.0045045]
#   Discard: |======| S-ADV -> NP-SBJ-2 ADVP VP [0.0045045]
#   Discard: |======| S-ADV -> NP-SBJ-3 ADVP VP [0.00900901]
#   Discard: |======| S-ADV -> NP-SBJ-3 ADVP VP [0.00900901]
#   Discard: |======| S-ADV -> NP-SBJ-3 ADVP VP [0.00900901]
#   Discard: |======| S-ADV -> NP-SBJ-3 ADVP VP [0.00900901]
#   Discard: |======| S-ADV -> NP-SBJ-3 ADVP VP [0.00900901]
#   Discard: |======| S-ADV -> NP-SBJ-3 ADVP VP [0.00900901]
#   Discard: |======| S-ADV -> NP-SBJ-3 ADVP VP [0.00900901]
#   Discard: |======| S -> NP-SBJ-71 VP [0.000115607]
#   Discard: |======| NP-SBJ -> NP PP S-2 [0.000261712]
#   Discard: |======| NP-SBJ -> NP PP S-2 [0.000261712]
#   Discard: |======| NP-SBJ -> NP PP S-2 [0.000261712]
#   Discard: |======| ADVP-TMP -> NP-ADV PRN [0.00160772]
#    Insert: |======| ADVP-TMP -> NP-ADV PRN [0.00160772]
#   Discard: |======| ADVP-TMP -> NP-ADV PRN [0.00160772]
#   Discard: |======| ADVP-TMP -> NP-ADV PRN [0.00160772]
#   Discard: |======| S -> NP-SBJ ADJP-PRD PP [0.000115607]
#   Discard: |======| S -> NP-SBJ ADJP-PRD PP [0.000115607]
#   Discard: |======| S -> NP-SBJ ADJP-PRD PP [0.000115607]
#   Discard: |======| S -> NP-SBJ ADJP-PRD PP [0.000115607]
#   Discard: |======| S-ADV -> NP-SBJ-3 ADJP-PRD [0.0045045]
#   Discard: |======| S-ADV -> NP-SBJ-3 ADJP-PRD [0.0045045]
#   Discard: |======| S-ADV -> NP-SBJ-3 ADJP-PRD [0.0045045]
#   Discard: |======| S-ADV -> NP-SBJ-3 ADJP-PRD [0.0045045]
#   Discard: |======| S-ADV -> NP-SBJ-3 ADJP-PRD [0.0045045]
#   Discard: |======| S -> NP-SBJ ADVP-MNR VP [0.000578035]
#   Discard: |======| S -> NP-SBJ ADVP-MNR VP [0.000578035]
#   Discard: |======| S -> NP-SBJ ADVP-MNR VP [0.000578035]
#   Discard: |======| S -> NP-SBJ ADVP-MNR VP [0.000578035]
#   Discard: |======| S -> NP-SBJ ADVP-MNR VP [0.000578035]
#   Discard: |======| S -> NP-SBJ-75 VP [0.000115607]
#    Insert: |======| NP-SBJ-75 -> NP NN [1.0]
#   Discard: |======| S-TPC-3 -> NP-SBJ ADVP-TMP VP [0.0416667]
#   Discard: |======| S-TPC-3 -> NP-SBJ ADVP-TMP VP [0.0416667]
#   Discard: |======| S-TPC-3 -> NP-SBJ ADVP-TMP VP [0.0416667]
#   Discard: |======| S-TPC-3 -> NP-SBJ ADVP-TMP VP [0.0416667]
#   Discard: |======| S-TPC-3 -> NP-SBJ ADVP-TMP VP [0.0416667]
#   Discard: |======| S-TPC-3 -> NP-SBJ ADVP-TMP VP [0.0416667]
#   Discard: |======| S-TPC-3 -> NP-SBJ ADVP-TMP VP [0.0416667]
#   Discard: |======| S-TPC-3 -> NP-SBJ ADVP-TMP VP [0.0416667]
#   Discard: |======| S -> NP-SBJ-3 ADVP VP [0.000115607]
#   Discard: |======| S -> NP-SBJ-3 ADVP VP [0.000115607]
#   Discard: |======| S -> NP-SBJ-3 ADVP VP [0.000115607]
#   Discard: |======| S -> NP-SBJ-3 ADVP VP [0.000115607]
#   Discard: |======| S -> NP-SBJ-3 ADVP VP [0.000115607]
#   Discard: |======| S -> NP-SBJ-3 ADVP VP [0.000115607]
#   Discard: |======| S -> NP-SBJ-3 ADVP VP [0.000115607]
#   Discard: |======| SBAR -> SBAR SBAR [0.000424628]
#   Discard: |======| S -> NP-SBJ ADJP-PRD S-1 [0.000115607]
#   Discard: |======| S -> NP-SBJ ADJP-PRD S-1 [0.000115607]
#   Discard: |======| S -> NP-SBJ ADJP-PRD S-1 [0.000115607]
#   Discard: |======| S -> NP-SBJ ADJP-PRD S-1 [0.000115607]
#    Insert: |======| NP-SBJ-78 -> NP VP [0.5]
#   Discard: |======| NP-SBJ-78 -> NP VP [0.5]
#    Insert: |======| NP-SBJ-78 -> NP VP [0.5]
#   Discard: |======| NP-SBJ-78 -> NP VP [0.5]
#   Discard: |======| NP-SBJ-78 -> NP VP [0.5]
#   Discard: |======| S-NOM -> NP-SBJ-2 ADVP-TMP VP [0.00319489]
#   Discard: |======| S-NOM -> NP-SBJ-2 ADVP-TMP VP [0.00319489]
#   Discard: |======| S-NOM -> NP-SBJ-2 ADVP-TMP VP [0.00319489]
#   Discard: |======| S-NOM -> NP-SBJ-2 ADVP-TMP VP [0.00319489]
#   Discard: |======| S-NOM -> NP-SBJ-2 ADVP-TMP VP [0.00319489]
#   Discard: |======| S-NOM -> NP-SBJ-2 ADVP-TMP VP [0.00319489]
#   Discard: |======| S-NOM -> NP-SBJ-2 ADVP-TMP VP [0.00319489]
#   Discard: |======| S-NOM -> NP-SBJ-2 ADVP-TMP VP [0.00319489]
#    Insert: |======| S-NOM-PRD -> NP-SBJ VP [1.0]
#   Discard: |======| S-NOM-PRD -> NP-SBJ VP [1.0]
#    Insert: |======| S-NOM-PRD -> NP-SBJ VP [1.0]
#   Discard: |======| S-NOM-PRD -> NP-SBJ VP [1.0]
#   Discard: |======| S-NOM-PRD -> NP-SBJ VP [1.0]
#   Discard: |======| NP-SBJ -> ADJP NN [0.000130856]
#   Discard: |======| NP-SBJ -> NP SBAR-ADV [0.000130856]
#   Discard: |======| NP-SBJ -> NP SBAR-ADV [0.000130856]
#   Discard: |======| NP-SBJ -> NP SBAR-ADV [0.000130856]
#   Discard: |======| NP-SBJ -> NP SBAR-ADV [0.000130856]
#   Discard: |======| S -> NP-SBJ-80 VP [0.000115607]
#   Discard: |======| S -> NP-SBJ-80 VP [0.000115607]
#   Discard: |======| S -> NP-SBJ-80 VP [0.000115607]
#   Discard: |======| NP-SBJ -> NP PRN PP [0.000130856]
#   Discard: |======| NP-SBJ -> NP PRN PP [0.000130856]
#   Discard: |======| NP-SBJ -> NP PRN PP [0.000130856]
#    Insert: |======| NP-SBJ-84 -> NP PP [0.5]
#   Discard: |======| NP-SBJ-84 -> NP PP [0.5]
#    Insert: |======| NP-SBJ-84 -> NP PP [0.5]
#   Discard: |======| NP-SBJ-84 -> NP PP [0.5]
#   Discard: |======| NP -> NP PP PP SBAR-ADV [4.21514e-05]
#   Discard: |======| S -> NP-SBJ-87 VP [0.000115607]
#   Discard: |======| S -> NP-SBJ-87 VP [0.000115607]
#   Discard: |======| S -> NP-SBJ-87 VP [0.000115607]
#   Discard: |======| S -> NP-SBJ PP VP [0.000346821]
#   Discard: |======| S -> NP-SBJ PP VP [0.000346821]
#   Discard: |======| S -> NP-SBJ PP VP [0.000346821]
#   Discard: |======| S -> NP-SBJ PP VP [0.000346821]
#   Discard: |======| S -> NP-SBJ PP VP [0.000346821]
#   Discard: |======| S -> NP-SBJ PP VP [0.000346821]
#   Discard: |======| NP-SBJ -> NP PP-LOC NP-TMP [0.000130856]
#   Discard: |======| NP-SBJ -> NP PP-LOC NP-TMP [0.000130856]
#   Discard: |======| S-ADV -> NP-SBJ ADVP-TMP NP-PRD [0.0045045]
#   Discard: |======| S-ADV -> NP-SBJ ADVP-TMP NP-PRD [0.0045045]
#   Discard: |======| S-ADV -> NP-SBJ ADVP-TMP NP-PRD [0.0045045]
#   Discard: |======| S-ADV -> NP-SBJ ADVP-TMP NP-PRD [0.0045045]
#   Discard: |======| S-ADV -> NP-SBJ ADVP-TMP NP-PRD [0.0045045]
#   Discard: |======| S-ADV -> NP-SBJ ADVP-TMP NP-PRD [0.0045045]
#   Discard: |======| S-ADV -> NP-SBJ ADVP-TMP NP-PRD [0.0045045]
#   Discard: |======| S-ADV -> NP-SBJ ADVP-TMP NP-PRD [0.0045045]
#   Discard: |======| S-TPC-3 -> NP-SBJ-2 VP [0.0416667]
#   Discard: |======| S-TPC-3 -> NP-SBJ-2 VP [0.0416667]
#   Discard: |======| S-TPC-3 -> NP-SBJ-2 VP [0.0416667]
#   Discard: |======| S-TPC-3 -> NP-SBJ-2 VP [0.0416667]
#   Discard: |======| S-TPC-3 -> NP-SBJ-2 VP [0.0416667]
#   Discard: |======| NP-SBJ-1 -> DT ADJP NN [0.00097371]
#   Discard: |======| NP-SBJ -> NP NP-TMP [0.000261712]
#   Discard: |======| NP-SBJ -> NP NP-TMP [0.000261712]
#   Discard: |======| NP-SBJ -> NP NP-TMP [0.000261712]
#   Discard: |======| NP-SBJ -> NP NP-TMP [0.000261712]
#   Discard: |======| NP-SBJ -> NP NP-TMP [0.000261712]
#   Discard: |======| NP-ADV -> NP PP-LOC [0.00497512]
#   Discard: |======| NP-ADV -> NP PP-LOC [0.00497512]
#   Discard: |======| S-ADV -> NP-SBJ ADVP PP-PRD [0.0045045]
#   Discard: |======| S-ADV -> NP-SBJ ADVP PP-PRD [0.0045045]
#   Discard: |======| S-ADV -> NP-SBJ ADVP PP-PRD [0.0045045]
# ...
#   Discard: |======| NP-SBJ -> NP PP-LOC NP-TMP [0.000130856]
#   Discard: |======| S-ADV -> NP-SBJ ADVP-TMP NP-PRD [0.0045045]
#   Discard: |======| S-ADV -> NP-SBJ ADVP-TMP NP-PRD [0.0045045]
#   Discard: |======| S-ADV -> NP-SBJ ADVP-TMP NP-PRD [0.0045045]
#   Discard: |======| S-ADV -> NP-SBJ ADVP-TMP NP-PRD [0.0045045]
#   Discard: |======| S-ADV -> NP-SBJ ADVP-TMP NP-PRD [0.0045045]
#   Discard: |======| S-ADV -> NP-SBJ ADVP-TMP NP-PRD [0.0045045]
#   Discard: |======| S-ADV -> NP-SBJ ADVP-TMP NP-PRD [0.0045045]
#   Discard: |======| S-ADV -> NP-SBJ ADVP-TMP NP-PRD [0.0045045]
#   Discard: |======| S-TPC-3 -> NP-SBJ-2 VP [0.0416667]
#   Discard: |======| S-TPC-3 -> NP-SBJ-2 VP [0.0416667]
#   Discard: |======| S-TPC-3 -> NP-SBJ-2 VP [0.0416667]
#   Discard: |======| S-TPC-3 -> NP-SBJ-2 VP [0.0416667]
#   Discard: |======| S-TPC-3 -> NP-SBJ-2 VP [0.0416667]
#   Discard: |======| NP-SBJ-1 -> DT ADJP NN [0.00097371]
#   Discard: |======| NP-SBJ -> NP NP-TMP [0.000261712]
#   Discard: |======| NP-SBJ -> NP NP-TMP [0.000261712]
#   Discard: |======| NP-SBJ -> NP NP-TMP [0.000261712]
#   Discard: |======| NP-SBJ -> NP NP-TMP [0.000261712]
#   Discard: |======| NP-SBJ -> NP NP-TMP [0.000261712]
#   Discard: |======| NP-ADV -> NP PP-LOC [0.00497512]
#   Discard: |======| NP-ADV -> NP PP-LOC [0.00497512]
#   Discard: |======| S-ADV -> NP-SBJ ADVP PP-PRD [0.0045045]
#   Discard: |======| S-ADV -> NP-SBJ ADVP PP-PRD [0.0045045]
#   Discard: |======| S-ADV -> NP-SBJ ADVP PP-PRD [0.0045045]
#   Discard: |======| FRAG -> SBAR-ADV [0.0102041]
#   Discard: |======| NP-PRD -> NP PP ADJP VP [0.00178571]
#   Discard: |======| NP-PRD -> NP PP ADJP VP [0.00178571]
#   Discard: |======| NP-PRD -> NP PP ADJP VP [0.00178571]
#   Discard: |======| NP-PRD -> NP PP ADJP VP [0.00178571]
#   Discard: |======| NP-SBJ-1 -> NP ADJP [0.00681597]
#   Discard: |======| NP-SBJ-1 -> NP ADJP [0.00681597]
#   Discard: |======| NP-SBJ-1 -> NP ADJP [0.00681597]
#   Discard: |======| NP-SBJ-1 -> NP ADJP [0.00681597]
#   Discard: |======| NP-SBJ-1 -> NP ADJP [0.00681597]
#   Discard: |======| NP-SBJ-2 -> NP ADJP [0.00909091]
#   Discard: |======| NP-SBJ-2 -> NP ADJP [0.00909091]
#   Discard: |======| NP-SBJ-2 -> NP ADJP [0.00909091]
#   Discard: |======| NP-SBJ-2 -> NP ADJP [0.00909091]
#   Discard: |======| NP-SBJ-2 -> NP ADJP [0.00909091]
#   Discard: |======| ADJP -> JJ PP-TMP [0.00291121]
#   Discard: |======| NP -> NP PP-LOC PRN [4.21514e-05]
#   Discard: |======| S -> SBAR-ADV NP-SBJ VP [0.000115607]
#   Discard: |======| S -> SBAR-ADV NP-SBJ VP [0.000115607]
#   Discard: |======| S -> SBAR-ADV NP-SBJ VP [0.000115607]
#   Discard: |======| S -> SBAR-ADV NP-SBJ VP [0.000115607]
#   Discard: |======| S -> SBAR-ADV NP-SBJ VP [0.000115607]
#   Discard: |======| S -> SBAR-ADV NP-SBJ VP [0.000115607]
#   Discard: |======| S -> PP NP-SBJ-1 VP [0.000115607]
#   Discard: |======| S -> PP NP-SBJ-1 VP [0.000115607]
#   Discard: |======| S -> PP NP-SBJ-1 VP [0.000115607]
#   Discard: |======| S -> PP NP-SBJ-1 VP [0.000115607]
#   Discard: |======| S -> PP NP-SBJ-1 VP [0.000115607]
#   Discard: |======| S -> PP NP-SBJ-1 VP [0.000115607]
#   Discard: |======| NP-PRD -> NP PP NP [0.00178571]
#   Discard: |======| NP-PRD -> NP PP NP [0.00178571]
#   Discard: |======| NP-PRD -> NP PP NP [0.00178571]
#   Discard: |======| NP-PRD -> NP PP NP [0.00178571]
#   Discard: |======| NP-PRD -> NP PP NP [0.00178571]
#   Discard: |======| NP-PRD -> NP PP NP [0.00178571]
#   Discard: |======| NP-PRD -> NP PP-TMP [0.00178571]
#   Discard: |======| NP-PRD -> NP PP-TMP [0.00178571]
#   Discard: |======| NP-PRD -> NP PP-TMP [0.00178571]
#   Discard: |======| NP-LGS -> NP PP PP [0.0042735]
#   Discard: |======| NP-LGS -> NP PP PP [0.0042735]
#   Discard: |======| NP-LGS -> NP PP PP [0.0042735]
#   Discard: |======| S-CLR -> NP-SBJ-1 VP [0.010989]
#   Discard: |======| S-CLR -> NP-SBJ-1 VP [0.010989]
#   Discard: |======| S-CLR -> NP-SBJ-1 VP [0.010989]
#   Discard: |======| S-CLR -> NP-SBJ-1 VP [0.010989]
#   Discard: |======| S-CLR -> NP-SBJ-1 VP [0.010989]
#   Discard: |======| S-ADV-2 -> NP-SBJ VP [1.0]
#   Discard: |======| S-ADV-2 -> NP-SBJ VP [1.0]
#   Discard: |======| S-ADV-2 -> NP-SBJ VP [1.0]
#   Discard: |======| S-ADV-2 -> NP-SBJ VP [1.0]
#   Discard: |======| NP-SBJ -> NP NNP NN [0.000130856]
#   Discard: |======| S -> NP-SBJ-3 ADVP-TMP VP [0.000115607]
#   Discard: |======| S -> NP-SBJ-3 ADVP-TMP VP [0.000115607]
#   Discard: |======| S -> NP-SBJ-3 ADVP-TMP VP [0.000115607]
#   Discard: |======| S -> NP-SBJ-3 ADVP-TMP VP [0.000115607]
#   Discard: |======| S -> NP-SBJ-3 ADVP-TMP VP [0.000115607]
#   Discard: |======| S -> NP-SBJ-3 ADVP-TMP VP [0.000115607]
#   Discard: |======| S -> NP-SBJ-3 ADVP-TMP VP [0.000115607]
#   Discard: |======| S -> NP-SBJ-3 ADVP-TMP VP [0.000115607]
#   Discard: |======| PP-TMP -> PP PP [0.00119474]
#   Discard: |======| PP-TMP -> PP PP [0.00119474]
#   Discard: |======| PP-TMP -> PP PP [0.00119474]
#   Discard: |======| PP -> ADVP-TMP IN NP [0.000193836]
#   Discard: |======| S-TMP -> NP-SBJ VP [0.5]
#   Discard: |======| S-TMP -> NP-SBJ VP [0.5]
#   Discard: |======| S-TMP -> NP-SBJ VP [0.5]
#   Discard: |======| S-TMP -> NP-SBJ VP [0.5]
#   Discard: |======| S -> NP-SBJ ADJP-PRD S-2 [0.000115607]
#   Discard: |======| S -> NP-SBJ ADJP-PRD S-2 [0.000115607]
#   Discard: |======| S -> NP-SBJ ADJP-PRD S-2 [0.000115607]
#   Discard: |======| S -> NP-SBJ ADJP-PRD S-2 [0.000115607]
#   Discard: |======| NP-LGS -> NP NN S [0.0042735]
#   Discard: |======| S -> NP-SBJ ADJP-PRD ADVP [0.000115607]
#   Discard: |======| S -> NP-SBJ ADJP-PRD ADVP [0.000115607]
#   Discard: |======| S -> NP-SBJ ADJP-PRD ADVP [0.000115607]
#   Discard: |======| S -> NP-SBJ ADJP-PRD ADVP [0.000115607]
#   Discard: |======| S -> NP-SBJ ADJP-PRD ADVP [0.000115607]
#   Discard: |======| NP -> NP QP [4.21514e-05]
#   Discard: |======| S-NOM -> NP-SBJ ADVP-MNR VP [0.00319489]
#   Discard: |======| S-NOM -> NP-SBJ ADVP-MNR VP [0.00319489]
#   Discard: |======| S-NOM -> NP-SBJ ADVP-MNR VP [0.00319489]
#   Discard: |======| S-NOM -> NP-SBJ ADVP-MNR VP [0.00319489]
#   Discard: |======| S-NOM -> NP-SBJ ADVP-MNR VP [0.00319489]
#   Discard: |======| NP-SBJ -> NP JJ JJ NN [0.000130856]
#   Discard: |======| NP-EXT -> NP PRN NP-ADV [0.00757576]
#   Discard: |======| NP-EXT -> NP PRN NP-ADV [0.00757576]
#   Discard: |======| NP-EXT -> NP PRN NP-ADV [0.00757576]
#   Discard: |======| NP-EXT -> NP PRN NP-ADV [0.00757576]
#   Discard: |======| NP-EXT -> NP PRN NP-ADV [0.00757576]
#   Discard: |======| NP-EXT -> NP PRN NP-ADV [0.00757576]
#   Discard: |======| NP-SBJ -> NP NP-TMP S-1 [0.000130856]
#   Discard: |======| NP-SBJ -> NP NP-TMP S-1 [0.000130856]
#   Discard: |======| NP-SBJ -> NP NP-TMP S-1 [0.000130856]
#   Discard: |======| S -> NP-SBJ=1 PP=3 [0.000115607]
#   Discard: |======| NP-SBJ=1 -> NP PP [0.333333]
#   Discard: |======| NP-SBJ=1 -> NP PP [0.333333]
#   Discard: |======| NP-SBJ=1 -> NP PP [0.333333]
#   Discard: |======| NP-PRD -> NP VP SBAR [0.00178571]
#   Discard: |======| S -> NP-TMP NP-SBJ ADVP VP [0.000115607]
#   Discard: |======| S -> NP-TMP NP-SBJ ADVP VP [0.000115607]
#   Discard: |======| S -> NP-TMP NP-SBJ ADVP VP [0.000115607]
#   Discard: |======| S -> NP-TMP NP-SBJ ADVP VP [0.000115607]
#   Discard: |======| S -> NP-TMP NP-SBJ ADVP VP [0.000115607]
#   Discard: |======| S -> NP-TMP NP-SBJ ADVP VP [0.000115607]
#   Discard: |======| S -> NP-TMP NP-SBJ ADVP VP [0.000115607]
#   Discard: |======| S -> NP-TMP NP-SBJ ADVP VP [0.000115607]
#   Discard: |======| NP-SBJ-1 -> NP PP-TMP [0.00194742]
#   Discard: |======| NP-SBJ-1 -> NP PP-TMP [0.00194742]
#   Discard: |======| NP-SBJ-1 -> NP PP-TMP [0.00194742]
#   Discard: |======| S-TPC-2 -> NP-SBJ-3 VP [0.0235294]
#   Discard: |======| S-TPC-2 -> NP-SBJ-3 VP [0.0235294]
#   Discard: |======| S-TPC-2 -> NP-SBJ-3 VP [0.0235294]
#   Discard: |======| S-TPC-2 -> NP-SBJ-3 VP [0.0235294]
#   Discard: |======| S-TPC-2 -> NP-SBJ-3 VP [0.0235294]
#   Discard: |======| ADJP -> JJ NP [0.0014556]
#   Discard: |======| NP -> NP S-CLR NP-TMP [4.21514e-05]
#   Discard: |======| NP -> NP S-CLR NP-TMP [4.21514e-05]
#   Discard: |======| NP -> NP S-CLR NP-TMP [4.21514e-05]
#   Discard: |======| NP -> NP S-CLR NP-TMP [4.21514e-05]
#   Discard: |======| NP -> NP S-CLR NP-TMP [4.21514e-05]
#   Discard: |======| NP -> NP S-CLR [4.21514e-05]
#   Discard: |======| NP -> NP S-CLR [4.21514e-05]
#   Discard: |======| NP -> NP S-CLR [4.21514e-05]
#   Discard: |======| NP -> NP S-CLR [4.21514e-05]
#   Discard: |======| NP-LGS-2 -> NP PP [1.0]
#   Discard: |======| NP-LGS-2 -> NP PP [1.0]
#   Discard: |======| NP-LGS-2 -> NP PP [1.0]
#   Discard: |======| NP -> NP ADVP-PRD [4.21514e-05]
#   Discard: |======| VP -> VP SBAR [6.8918e-05]
#   Discard: |======| NP -> DT NN ADJP NN [4.21514e-05]
#   Discard: |======| NP-SBJ-3 -> NP NN [0.00925926]
#   Discard: |======| PP -> PP PRN [0.000193836]
#   Discard: |======| PP -> PP PRN [0.000193836]
#   Discard: |======| PP -> PP PRN [0.000193836]
#   Discard: |======| NP -> NP NN PP [4.21514e-05]
#   Discard: |======| S-PRP-3 -> NP-SBJ VP [1.0]
#   Discard: |======| S-PRP-3 -> NP-SBJ VP [1.0]
#   Discard: |======| S-PRP-3 -> NP-SBJ VP [1.0]
#   Discard: |======| S-PRP-3 -> NP-SBJ VP [1.0]
#   Discard: |======| VP -> VP CONJP VP [6.8918e-05]
#   Discard: |======| FRAG -> ADJP-PRD S [0.0102041]
#   Discard: |======| FRAG -> ADJP-PRD S [0.0102041]
#   Discard: |======| FRAG -> ADJP-PRD S [0.0102041]
#   Discard: |======| FRAG -> ADJP-PRD S [0.0102041]
#   Discard: |======| S -> PRN NP-SBJ-2 ADVP-TMP VP [0.000115607]
#   Discard: |======| S -> PRN NP-SBJ-2 ADVP-TMP VP [0.000115607]
#   Discard: |======| S -> PRN NP-SBJ-2 ADVP-TMP VP [0.000115607]
#   Discard: |======| S-TPC-1 -> ADVP NP-SBJ-2 ADVP VP [0.0044843]
#   Discard: |======| S-TPC-1 -> ADVP NP-SBJ-2 ADVP VP [0.0044843]
#   Discard: |======| S-TPC-1 -> ADVP NP-SBJ-2 ADVP VP [0.0044843]
#   Discard: |======| S-TPC-1 -> ADVP NP-SBJ-2 ADVP VP [0.0044843]
#   Discard: |======| NP -> NP NP-TMP S-1 [4.21514e-05]
#   Discard: |======| NP -> NP NP-TMP S-1 [4.21514e-05]
#   Discard: |======| NP -> NP NP-TMP S-1 [4.21514e-05]
#   Discard: |======| S-PRP -> ADVP NP-SBJ-4 VP [0.00892857]
#   Discard: |======| S-PRP -> ADVP NP-SBJ-4 VP [0.00892857]
#   Discard: |======| S-PRP -> ADVP NP-SBJ-4 VP [0.00892857]
#   Discard: |======| S-PRD -> NP-SBJ-1 VP [0.0434783]
#   Discard: |======| S-PRD -> NP-SBJ-1 VP [0.0434783]
#   Discard: |======| S-PRD -> NP-SBJ-1 VP [0.0434783]
#   Discard: |======| S-PRD -> NP-SBJ-1 VP [0.0434783]
#   Discard: |======| S-PRD -> NP-SBJ-1 VP [0.0434783]
#   Discard: |======| NP-SBJ -> DT UCP NN [0.000130856]
#   Discard: |======| VP -> ADVP JJ NP [6.8918e-05]
#   Discard: |======| VP -> ADVP JJ NP [6.8918e-05]
#   Discard: |======| FRAG -> ADJP [0.0204082]
#   Discard: |======| S -> NP-SBJ-6 VP [0.000115607]
#   Discard: |======| S -> NP-SBJ-6 VP [0.000115607]
#   Discard: |======| S -> NP-SBJ-6 VP [0.000115607]
#   Discard: |======| S -> NP-SBJ-7 VP [0.000115607]
#   Discard: |======| S -> NP-SBJ-7 VP [0.000115607]
#   Discard: |======| S -> NP-SBJ-7 VP [0.000115607]
#   Discard: |======| S-TPC-4 -> NP-TMP NP-SBJ-1 VP [0.2]
#   Discard: |======| S-TPC-4 -> NP-TMP NP-SBJ-1 VP [0.2]
#   Discard: |======| S-TPC-4 -> NP-TMP NP-SBJ-1 VP [0.2]
#   Discard: |======| S-TPC-4 -> NP-TMP NP-SBJ-1 VP [0.2]
#   Discard: |======| S-TPC-4 -> NP-TMP NP-SBJ-1 VP [0.2]
#   Discard: |======| S-TPC-4 -> NP-TMP NP-SBJ-1 VP [0.2]
#   Discard: |======| S-TPC-4 -> NP-TMP NP-SBJ-1 VP [0.2]
#   Discard: |======| S-TPC-4 -> NP-TMP NP-SBJ-1 VP [0.2]
#   Discard: |======| S-TPC-4 -> NP-TMP NP-SBJ-1 VP [0.2]
#   Discard: |======| S -> NP-TMP NP-SBJ-2 VP [0.000115607]
#   Discard: |======| S -> NP-TMP NP-SBJ-2 VP [0.000115607]
#   Discard: |======| S -> NP-TMP NP-SBJ-2 VP [0.000115607]
#   Discard: |======| S -> NP-TMP NP-SBJ-2 VP [0.000115607]
#   Discard: |======| S -> NP-TMP NP-SBJ-2 VP [0.000115607]
#   Discard: |======| S -> NP-TMP NP-SBJ-2 VP [0.000115607]
#   Discard: |======| S -> NP-TMP NP-SBJ-2 VP [0.000115607]
#   Discard: |======| S -> NP-TMP NP-SBJ-2 VP [0.000115607]
#   Discard: |======| S -> NP-TMP NP-SBJ-2 VP [0.000115607]
#   Discard: |======| NP -> NP NP-ADV PP [4.21514e-05]
#   Discard: |======| NP -> NP NP-ADV PP [4.21514e-05]
#   Discard: |======| NP -> NP NP-ADV PP [4.21514e-05]
#   Discard: |======| NP-PRD -> NP JJ NN [0.00178571]
#   Discard: |======| NP -> DT NAC [4.21514e-05]
#   Discard: |======| S-PRP-PRD -> NP-SBJ VP [1.0]
#   Discard: |======| S-PRP-PRD -> NP-SBJ VP [1.0]
#   Discard: |======| S-PRP-PRD -> NP-SBJ VP [1.0]
#   Discard: |======| S-PRP-PRD -> NP-SBJ VP [1.0]
#   Discard: |======| S -> SBAR-ADV NP-SBJ-1 VP [0.000115607]
#   Discard: |======| S -> SBAR-ADV NP-SBJ-1 VP [0.000115607]
#   Discard: |======| S -> SBAR-ADV NP-SBJ-1 VP [0.000115607]
#   Discard: |======| S -> SBAR-ADV NP-SBJ-1 VP [0.000115607]
#   Discard: |======| S -> SBAR-ADV NP-SBJ-1 VP [0.000115607]
#   Discard: |======| S -> SBAR-ADV NP-SBJ-1 VP [0.000115607]
#   Discard: |======| NP-SBJ=1-3 -> NP PP [1.0]
#   Discard: |======| NP-SBJ=1-3 -> NP PP [1.0]
#   Discard: |======| NP-SBJ=1-3 -> NP PP [1.0]
#   Discard: |======| NP-SBJ-3 -> NP ADJP [0.00925926]
#   Discard: |======| NP-SBJ-3 -> NP ADJP [0.00925926]
#   Discard: |======| NP-SBJ-3 -> NP ADJP [0.00925926]
#   Discard: |======| NP-SBJ-3 -> NP ADJP [0.00925926]
#   Discard: |======| NP-SBJ-3 -> NP ADJP [0.00925926]
#   Discard: |======| ADJP-PRD -> JJ PP PP [0.00332226]
#   Discard: |======| ADJP-PRD -> JJ PP PP [0.00332226]
#   Discard: |======| S -> PP-PRP NP-SBJ VP [0.000115607]
#   Discard: |======| S -> PP-PRP NP-SBJ VP [0.000115607]
#   Discard: |======| S -> PP-PRP NP-SBJ VP [0.000115607]
#   Discard: |======| NP -> JJ NP [4.21514e-05]
#   Discard: |======| S-TPC-2 -> NP-SBJ-1 ADVP VP [0.0235294]
#   Discard: |======| S-TPC-2 -> NP-SBJ-1 ADVP VP [0.0235294]
#   Discard: |======| S-TPC-2 -> NP-SBJ-1 ADVP VP [0.0235294]
#   Discard: |======| S-TPC-2 -> NP-SBJ-1 ADVP VP [0.0235294]
#   Discard: |======| S-TPC-2 -> NP-SBJ-1 ADVP VP [0.0235294]
#   Discard: |======| S-TPC-2 -> NP-SBJ-1 ADVP VP [0.0235294]
#   Discard: |======| S-TPC-2 -> NP-SBJ-1 ADVP VP [0.0235294]
#   Discard: |======| NP-LGS -> NP PP PP-TMP [0.0042735]
#   Discard: |======| ADJP -> NP JJ PP [0.0014556]
#   Discard: |======| NP-SBJ -> NP NP-TMP PP [0.000130856]
#   Discard: |======| NP-SBJ -> NP NP-TMP PP [0.000130856]
#   Discard: |======| NP-SBJ -> NP NP-TMP PP [0.000130856]
#   Discard: |======| NP -> NP PP NP-ADV [4.21514e-05]
#   Discard: |======| NP -> NP PP NP-ADV [4.21514e-05]
#   Discard: |======| NP -> NP PP NP-ADV [4.21514e-05]
#   Discard: |======| NP -> NP PP NP-ADV [4.21514e-05]
#   Discard: |======| NP -> NP PP NP-ADV [4.21514e-05]
#   Discard: |======| NP -> NP PP NP-ADV [4.21514e-05]
#   Discard: |======| NP-TMP -> NP VP [0.00273224]
#   Discard: |======| NP-TMP -> NP VP [0.00273224]
#   Discard: |======| NP-TMP -> NP VP [0.00273224]
#   Discard: |======| NP-TMP -> NP VP [0.00273224]
#   Discard: |======| NP-TMP -> NP VP [0.00273224]
#   Discard: |======| NP-SBJ-1 -> DT NN S [0.00097371]
#   Discard: |======| NP -> NP PP SBAR-2 [4.21514e-05]
#   Discard: |======| WHNP-1 -> WHNP PRN [0.00291545]
#   Discard: |======| ADVP-LOC -> ADVP PP [0.011236]
#   Discard: |======| ADVP-LOC -> ADVP PP [0.011236]
#   Discard: |======| ADVP-LOC -> JJ PP [0.011236]
#   Discard: |======| NP-TMP -> NP PP-LOC [0.00273224]
#   Discard: |======| NP-TMP -> NP PP-LOC [0.00273224]
#   Discard: |======| PP-PRD -> NP-ADV IN S-NOM [0.011236]
#   Discard: |======| S-TPC-3 -> NP-SBJ-1 VP [0.0416667]
#   Discard: |======| S-TPC-3 -> NP-SBJ-1 VP [0.0416667]
#   Discard: |======| S-TPC-3 -> NP-SBJ-1 VP [0.0416667]
#   Discard: |======| S-TPC-3 -> NP-SBJ-1 VP [0.0416667]
#   Discard: |======| S-TPC-3 -> NP-SBJ-1 VP [0.0416667]
#   Discard: |======| SBAR-ADV -> WHNP-1 S [0.00331126]
#   Discard: |======| PP -> NP IN ADJP [0.000193836]
#   Discard: |======| NP-LGS -> NP CONJP NP [0.0042735]
#   Discard: |======| NP-LGS -> NP SBAR [0.0042735]
#   Discard: |======| NP -> DT ADJP NX [4.21514e-05]
#   Discard: |======| NP -> DT ADJP NX [4.21514e-05]
#   Discard: |======| NP -> DT ADJP NX [4.21514e-05]
#   Discard: |======| PP-PRD -> JJ ADJP [0.011236]
#   Discard: |======| NP-SBJ -> NNP NX [0.000130856]
# (S
#   (NP-SBJ (DT the) (NN boy))
#   (NP-PRD
#     (NP (NNS jumps))
#     (PP (IN over) (NP (DT the) (NN board))))) (p=1.25001e-20)
# Probability: 1.2500082459723783e-20
